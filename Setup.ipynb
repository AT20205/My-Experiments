# %% [markdown]
# Step 1: Click on the link to get started C:\Users\Amit\projects\llm_engineering\README.md
#
# Important links:
#
# https://edwarddonner.com/2024/11/13/llm-engineering-resources/
#
# https://github.com/ed-donner/llm_engineering/blob/main/setup/SETUP-new.md
#
# https://edwarddonner.com/faq/
#
#
# Context window, cost, speed comparison for LLMs
#
# https://www.vellum.ai/llm-leaderboard
#
# https://artificialanalysis.ai/?cost=intelligence-vs-cost
#
# https://labs.scale.com/leaderboard/humanitys_last_exam
#
# https://agi.safe.ai/
#
# https://huggingface.co/spaces?search=leaderboard
#
# https://livebench.ai/#/?highunseenbias=true
#
# https://arena.ai/c/
#
# https://openrouter.ai/rankings

# %%
# imports

import os
import glob
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
from openai import OpenAI

# If you get an error running this cell, then please head over to the troubleshooting notebook!

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
# Create OpenAI client

from openai import OpenAI
openai = OpenAI()

# %%
filenames = glob.glob("knowledge-base/employees/*")
