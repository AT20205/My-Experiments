# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait, Select
from selenium.webdriver.support import expected_conditions as EC
import time
from bs4 import BeautifulSoup
import pandas as pd
from selenium.common.exceptions import TimeoutException, NoSuchElementException, StaleElementReferenceException
import os
import re

STATES = {
    "33": "TAMIL NADU"
#     "35": "ANDAMAN AND NICOBAR ISLANDS", "28": "ANDHRA PRADESH", "12": "ARUNACHAL PRADESH", 
#     "18": "ASSAM", "10": "BIHAR", "4": "CHANDIGARH", "22": "CHHATTISGARH", "7": "DELHI", 
#     "30": "GOA", "24": "GUJARAT", "6": "HARYANA", "2": "HIMACHAL PRADESH", "1": "JAMMU AND KASHMIR", 
#     "20": "JHARKHAND", "29": "KARNATAKA", "32": "KERALA", "37": "LADAKH", "31": "LAKSHADWEEP", 
#     "23": "MADHYA PRADESH", "27": "MAHARASHTRA", "14": "MANIPUR", "17": "MEGHALAYA", "15": "MIZORAM", 
#     "13": "NAGALAND", "21": "ODISHA", "34": "PUDUCHERRY", "3": "PUNJAB", "8": "RAJASTHAN", 
#     "11": "SIKKIM", "33": "TAMIL NADU", "36": "TELANGANA", 
#     "38": "THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU", "16": "TRIPURA", "5": "UTTARAKHAND", 
#     "9": "UTTAR PRADESH", "19": "WEST BENGAL"
}
Fn = "SEIAA_TN.xlsx"

ACTIVITIES = {
    "29": "7(a) Airports", 
    "15": "4(c) Asbestos milling / asbestos-based products",
    "33": "7(da) Bio-Medical Waste Treatment Facilities", 
    "39": "8(a) Building / Construction",
    "11": "3(b) Cement plants", 
    "19": "5(a) Chemical fertilizers", 
    "16": "4(d) Chlor-alkali industry",
    "14": "4(b)(ii) Coaltar processing units", 
    "8": "2(a) Coal washeries", 
    "13": "4(b) Coke oven plants",
    "37": "7(h) Common Effluent Treatment Plants (CETPs)",
    "32": "7(d ) Common hazardous waste treatment, storage and disposal facilities (TSDFs)",
    "34": "7(i) Common Municipal Solid Waste Management Facility (CMSWMF)", 
    "25": "5(g) Distilleries",
    "75": "5(ga) Grain based distilleries", 
    "31": "7(c ) Industrial estates/ parks/ complexes/ areas, export processing Zones (EPZs), Special Economic Zones",
    "26": "5(h) Integrated paint industry", 
    "22": "5(d) Manmade fibers manufacturing",
    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)", 
    "9": "2(b) Mineral beneficiation",
    "1": "1(a) Mining of minerals", 
    "7": "1(e) Nuclear power projects and processing of nuclear fuel",
    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production",
    "79": "2(c) Pellet Plant", 
    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)",
    "21": "5(c) Petro-chemical complexes (industries based on processing of petroleum fractions",
    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking",
    "12": "4(a) Petroleum refining industry", 
    "2": "6(a) Pipelines", 
    "35": "7(e) Ports, harbors, breakwaters, dredging",
    "27": "5(i) Pulp & Paper Industry", 
    "5": "1(c) River Valley/Irrigation projects", 
    "36": "7(f) Road",
    "30": "7(b) Ship breaking yards including ship breaking units", 
    "18": "4(f) Skin/hide processing including the tanning industry",
    "77": "1(a)(ii) Slurry pipelines passing through national parks / sanctuaries / coral reefs, ecologically sensitive areas",
    "17": "4(e) Soda ash Industry", 
    "28": "5(j) Sugar Industry", 
    "24": "5(f) Synthetic organic chemicals industry",
    "6": "1(d) Thermal Power Plants", 
    "40": "8(b) Townships/ Area Development Projects / Rehabilitation Centres"
}

driver = webdriver.Chrome()
driver.get("https://parivesh.nic.in/newupgrade/#/trackYourProposal/")
wait = WebDriverWait(driver, 20)

# Click Advance Search
advance_btn = wait.until(EC.element_to_be_clickable((By.XPATH, "//button[contains(., 'Show Advance Search')]")))
driver.execute_script("arguments[0].click();", advance_btn)

# Helper function to trigger Angular events
def trigger_angular_select(element, value=None, by_index=None, by_text=None):
    select_obj = Select(element)
    
    if value is not None:
        try:
            select_obj.select_by_value(str(value))
        except NoSuchElementException:
            # Fallback to text or index if value matching fails
            if by_text:
                select_obj.select_by_visible_text(by_text)
            elif by_index is not None:
                select_obj.select_by_index(by_index)
    elif by_text is not None:
        select_obj.select_by_visible_text(by_text)
    elif by_index is not None:
        select_obj.select_by_index(by_index)

    driver.execute_script(
        "arguments[0].dispatchEvent(new Event('change', { bubbles: true }));"
        "arguments[0].dispatchEvent(new Event('input', { bubbles: true }));",
        element
    )

# -----------------------------
# Select Major Clearance Type (Robust Selection)
# -----------------------------
major_clearance_elem = wait.until(
    EC.presence_of_element_located((By.XPATH, "//select[@formcontrolname='majorClearanceType']"))
)

# Wait until option elements are populated inside the dropdown
wait.until(lambda d: len(Select(major_clearance_elem).options) > 1)

try:
    trigger_angular_select(major_clearance_elem, value="1", by_index=1, by_text="Environment Clearance")
except Exception as e:
    # Fallback to direct index selection
    Select(major_clearance_elem).select_by_index(1)

# Select Issue Authority (SEIAA)
issue_auth_elem = wait.until(
    EC.presence_of_element_located((By.CSS_SELECTOR, "select[formcontrolname='issueAuthority']"))
)
trigger_angular_select(issue_auth_elem, value="SEIAA", by_text="SEIAA")

all_table_data = []
headers = []  

# -----------------------------
# Nested Loops
# -----------------------------
for state_value, state_name in STATES.items():
    print(f"\n🌍 Processing State: {state_name} (Value: {state_value})...")
    
    for act_value, act_desc in ACTIVITIES.items():
        print(f"  └── ⚙️ Searching Activity ID: {act_value} ({act_desc[:30]}...)")
        
        # Retry loop for state/activity dropdowns
        selection_success = False
        for attempt in range(3):
            try:
                state_dropdown = wait.until(
                    EC.presence_of_element_located((By.XPATH, "//select[@formcontrolname='state']"))
                )
                trigger_angular_select(state_dropdown, value=state_value)
                time.sleep(0.3)
                
                activity_dropdown = wait.until(
                    EC.presence_of_element_located((By.XPATH, "//select[@formcontrolname='activityId']"))
                )
                trigger_angular_select(activity_dropdown, value=act_value)
                time.sleep(0.3)
                
                selection_success = True
                break
            except (StaleElementReferenceException, TimeoutException):
                time.sleep(0.5)

        if not selection_success:
            print(f"  ❌ Failed to set selection for Activity {act_value}. Skipping...")
            continue

        search_button = wait.until(
            EC.element_to_be_clickable((By.XPATH, "//button[@type='submit' and contains(.,'Search')]"))
        )
        
        existing_tables = driver.find_elements(By.ID, "excel-table")
        old_table = existing_tables[0] if existing_tables else None

        driver.execute_script("arguments[0].click();", search_button)
        
        if old_table:
            try:
                wait.until(EC.staleness_of(old_table))
            except Exception:
                time.sleep(1) 

        try:
            wait.until(EC.visibility_of_element_located((By.ID, "excel-table")))
            time.sleep(0.5)
        except TimeoutException:
            print(f"  ℹ️ No results found for State: {state_value} + Activity: {act_value}. Proceeding...")
            continue

        # -----------------------------
        # PAGINATION
        # -----------------------------
        page_num = 1
        while True:
            rows_elements = driver.find_elements(By.XPATH, "//table[@id='excel-table']/tbody/tr")
            
            if not rows_elements:
                break
                
            first_row_text = rows_elements[0].text.lower()
            if "no record" in first_row_text or "no data" in first_row_text:
                break

            if not headers:
                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                table = soup.find("table", {"id": "excel-table"})
                if table and table.find("thead"):
                    for th in table.find("thead").find_all("th"):
                        headers.append(th.get_text(strip=True))

            total_rows = len(rows_elements)
            print(f"  📊 Page {page_num}: Scraping {total_rows} records...")

            for row in rows_elements:
                try:
                    cols = row.find_elements(By.TAG_NAME, "td")
                    row_data = [col.text.strip() for col in cols]
                    
                    if not row_data or len(row_data) <= 1:
                        continue
                    
                    row_data.append(state_name)
                    row_data.append(act_desc)
                    all_table_data.append(row_data)
                except Exception:
                    continue

            # Pagination control
            try:
                next_buttons = driver.find_elements(By.XPATH, "//button[@aria-label='Next page']")
                if not next_buttons:
                    break
                    
                next_btn = next_buttons[0]
                
                is_disabled = (
                    next_btn.get_attribute("disabled") in ["true", "disabled", True] or
                    next_btn.get_attribute("aria-disabled") == "true" or
                    "mat-button-disabled" in (next_btn.get_attribute("class") or "")
                )
                
                if is_disabled:
                    print(f"  🎉 Reached final page ({page_num}) for Activity {act_value}.")
                    break

                current_signature = rows_elements[0].text if rows_elements else ""

                driver.execute_script("arguments[0].click();", next_btn)
                page_num += 1

                def wait_for_page_transition(d):
                    try:
                        new_rows = d.find_elements(By.XPATH, "//table[@id='excel-table']/tbody/tr")
                        if not new_rows:
                            return False
                        return new_rows[0].text != current_signature
                    except (StaleElementReferenceException, NoSuchElementException):
                        return False

                WebDriverWait(driver, 20).until(wait_for_page_transition)
                time.sleep(0.5)

            except TimeoutException:
                print(f"  ⚠️ Timeout on page {page_num}. Moving to next activity...")
                break
            except Exception as ex:
                print(f"  ⚠️ Pagination exception on page {page_num}: {ex}")
                break

        time.sleep(0.3)


# -----------------------------
# Save Results
# -----------------------------
if all_table_data:
    expected_header_count = len(all_table_data[0])
    
    if len(headers) < expected_header_count:
        headers.append("State_Name")
    if len(headers) < expected_header_count:
        headers.append("Activity Description")
        
    df = pd.DataFrame(all_table_data, columns=headers[:expected_header_count])
    
    # -------------------------------------------------------------
    # CLEANUP: Remove illegal Excel control characters (\x00-\x08, \x0B-\x0C, \x0E-\x1F)
    # -------------------------------------------------------------
    illegal_xml_chars_re = re.compile(r'[\x00-\x08\x0B-\x0C\x0E-\x1F]')
    
    df = df.map(lambda x: illegal_xml_chars_re.sub('', x) if isinstance(x, str) else x)

    print("\n--- Final Extracted Dataset Preview ---")
    print(df.head()) 

    output_dir = r"F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver"
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        
    file_path = os.path.join(output_dir, Fn)
    df.to_excel(file_path, index=False)
    print(f"\n✅ Total {len(df)} rows scraped and saved to {file_path}")
else:
    print("\n❌ Automation complete. Zero data entries found across the state/activity matrix.")

driver.quit()
# Out:
# 🌍 Processing State: TAMIL NADU (Value: 33)...
#   └── ⚙️ Searching Activity ID: 29 (7(a) Airports...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 29.
#   └── ⚙️ Searching Activity ID: 15 (4(c) Asbestos milling / asbest...)
#   ℹ️ No results found for State: 33 + Activity: 15. Proceeding...
#   └── ⚙️ Searching Activity ID: 33 (7(da) Bio-Medical Waste Treatm...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 5 records...
#   🎉 Reached final page (2) for Activity 33.
#   └── ⚙️ Searching Activity ID: 39 (8(a) Building / Construction...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 10 records...
#   📊 Page 6: Scraping 10 records...
#   📊 Page 7: Scraping 10 records...
#   📊 Page 8: Scraping 10 records...
#   📊 Page 9: Scraping 10 records...
#   📊 Page 10: Scraping 10 records...
#   📊 Page 11: Scraping 10 records...
#   📊 Page 12: Scraping 10 records...
#   📊 Page 13: Scraping 10 records...
#   📊 Page 14: Scraping 10 records...
#   📊 Page 15: Scraping 10 records...
#   📊 Page 16: Scraping 10 records...
#   📊 Page 17: Scraping 10 records...
#   📊 Page 18: Scraping 10 records...
#   📊 Page 19: Scraping 10 records...
#   📊 Page 20: Scraping 10 records...
#   📊 Page 21: Scraping 10 records...
#   📊 Page 22: Scraping 10 records...
#   📊 Page 23: Scraping 10 records...
#   📊 Page 24: Scraping 10 records...
#   📊 Page 25: Scraping 10 records...
#   📊 Page 26: Scraping 10 records...
#   📊 Page 27: Scraping 10 records...
#   📊 Page 28: Scraping 10 records...
#   📊 Page 29: Scraping 10 records...
#   📊 Page 30: Scraping 10 records...
#   📊 Page 31: Scraping 10 records...
#   📊 Page 32: Scraping 10 records...
#   📊 Page 33: Scraping 10 records...
#   📊 Page 34: Scraping 10 records...
#   📊 Page 35: Scraping 10 records...
#   📊 Page 36: Scraping 10 records...
#   📊 Page 37: Scraping 10 records...
#   📊 Page 38: Scraping 10 records...
#   📊 Page 39: Scraping 10 records...
#   📊 Page 40: Scraping 10 records...
#   📊 Page 41: Scraping 10 records...
#   📊 Page 42: Scraping 10 records...
#   📊 Page 43: Scraping 10 records...
#   📊 Page 44: Scraping 10 records...
#   📊 Page 45: Scraping 10 records...
#   📊 Page 46: Scraping 10 records...
#   📊 Page 47: Scraping 10 records...
#   📊 Page 48: Scraping 10 records...
#   📊 Page 49: Scraping 10 records...
#   📊 Page 50: Scraping 10 records...
#   📊 Page 51: Scraping 10 records...
#   📊 Page 52: Scraping 10 records...
#   📊 Page 53: Scraping 10 records...
#   📊 Page 54: Scraping 10 records...
#   📊 Page 55: Scraping 10 records...
#   📊 Page 56: Scraping 10 records...
#   📊 Page 57: Scraping 10 records...
#   📊 Page 58: Scraping 10 records...
#   📊 Page 59: Scraping 10 records...
#   📊 Page 60: Scraping 10 records...
#   📊 Page 61: Scraping 10 records...
#   📊 Page 62: Scraping 10 records...
#   📊 Page 63: Scraping 10 records...
#   📊 Page 64: Scraping 10 records...
#   📊 Page 65: Scraping 10 records...
#   📊 Page 66: Scraping 10 records...
#   📊 Page 67: Scraping 10 records...
#   📊 Page 68: Scraping 10 records...
#   📊 Page 69: Scraping 10 records...
#   📊 Page 70: Scraping 10 records...
#   📊 Page 71: Scraping 10 records...
#   📊 Page 72: Scraping 10 records...
#   📊 Page 73: Scraping 10 records...
#   📊 Page 74: Scraping 10 records...
#   📊 Page 75: Scraping 10 records...
#   📊 Page 76: Scraping 10 records...
#   📊 Page 77: Scraping 10 records...
#   📊 Page 78: Scraping 5 records...
#   🎉 Reached final page (78) for Activity 39.
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   📊 Page 1: Scraping 10 records...
#   🎉 Reached final page (1) for Activity 11.
#   └── ⚙️ Searching Activity ID: 19 (5(a) Chemical fertilizers...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 19.
#   └── ⚙️ Searching Activity ID: 16 (4(d) Chlor-alkali industry...)
#   ℹ️ No results found for State: 33 + Activity: 16. Proceeding...
#   └── ⚙️ Searching Activity ID: 14 (4(b)(ii) Coaltar processing un...)
#   ℹ️ No results found for State: 33 + Activity: 14. Proceeding...
#   └── ⚙️ Searching Activity ID: 8 (2(a) Coal washeries...)
#   ℹ️ No results found for State: 33 + Activity: 8. Proceeding...
#   └── ⚙️ Searching Activity ID: 13 (4(b) Coke oven plants...)
#   ℹ️ No results found for State: 33 + Activity: 13. Proceeding...
#   └── ⚙️ Searching Activity ID: 37 (7(h) Common Effluent Treatment...)
#   ℹ️ No results found for State: 33 + Activity: 37. Proceeding...
#   └── ⚙️ Searching Activity ID: 32 (7(d ) Common hazardous waste t...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 32.
#   └── ⚙️ Searching Activity ID: 34 (7(i) Common Municipal Solid Wa...)
#   ℹ️ No results found for State: 33 + Activity: 34. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 5 records...
#   🎉 Reached final page (1) for Activity 25.
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 75.
#   └── ⚙️ Searching Activity ID: 31 (7(c ) Industrial estates/ park...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 31.
#   └── ⚙️ Searching Activity ID: 26 (5(h) Integrated paint industry...)
#   📊 Page 1: Scraping 3 records...
#   🎉 Reached final page (1) for Activity 26.
#   └── ⚙️ Searching Activity ID: 22 (5(d) Manmade fibers manufactur...)
#   ℹ️ No results found for State: 33 + Activity: 22. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 10 records...
#   📊 Page 6: Scraping 8 records...
#   🎉 Reached final page (6) for Activity 10.
#   └── ⚙️ Searching Activity ID: 9 (2(b) Mineral beneficiation...)
#   📊 Page 1: Scraping 4 records...
#   🎉 Reached final page (1) for Activity 9.
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 10 records...
#   📊 Page 6: Scraping 10 records...
#   📊 Page 7: Scraping 10 records...
#   📊 Page 8: Scraping 10 records...
#   📊 Page 9: Scraping 10 records...
#   📊 Page 10: Scraping 10 records...
#   📊 Page 11: Scraping 10 records...
#   📊 Page 12: Scraping 10 records...
#   📊 Page 13: Scraping 10 records...
#   📊 Page 14: Scraping 10 records...
#   📊 Page 15: Scraping 10 records...
#   📊 Page 16: Scraping 10 records...
#   📊 Page 17: Scraping 10 records...
#   📊 Page 18: Scraping 10 records...
#   📊 Page 19: Scraping 10 records...
#   📊 Page 20: Scraping 10 records...
#   📊 Page 21: Scraping 10 records...
#   📊 Page 22: Scraping 10 records...
#   📊 Page 23: Scraping 10 records...
#   📊 Page 24: Scraping 10 records...
#   📊 Page 25: Scraping 10 records...
#   📊 Page 26: Scraping 10 records...
#   📊 Page 27: Scraping 10 records...
#   📊 Page 28: Scraping 10 records...
#   📊 Page 29: Scraping 10 records...
#   📊 Page 30: Scraping 10 records...
#   📊 Page 31: Scraping 10 records...
#   📊 Page 32: Scraping 10 records...
#   📊 Page 33: Scraping 10 records...
#   📊 Page 34: Scraping 10 records...
#   📊 Page 35: Scraping 10 records...
#   📊 Page 36: Scraping 10 records...
#   📊 Page 37: Scraping 10 records...
#   📊 Page 38: Scraping 10 records...
#   📊 Page 39: Scraping 10 records...
#   📊 Page 40: Scraping 10 records...
#   📊 Page 41: Scraping 10 records...
#   📊 Page 42: Scraping 10 records...
#   📊 Page 43: Scraping 10 records...
#   📊 Page 44: Scraping 10 records...
#   📊 Page 45: Scraping 10 records...
#   📊 Page 46: Scraping 10 records...
#   📊 Page 47: Scraping 10 records...
#   📊 Page 48: Scraping 10 records...
#   📊 Page 49: Scraping 10 records...
#   📊 Page 50: Scraping 10 records...
#   📊 Page 51: Scraping 10 records...
#   📊 Page 52: Scraping 10 records...
#   📊 Page 53: Scraping 10 records...
#   📊 Page 54: Scraping 10 records...
#   📊 Page 55: Scraping 10 records...
#   📊 Page 56: Scraping 10 records...
#   📊 Page 57: Scraping 10 records...
#   📊 Page 58: Scraping 10 records...
#   📊 Page 59: Scraping 10 records...
#   📊 Page 60: Scraping 10 records...
#   📊 Page 61: Scraping 10 records...
#   📊 Page 62: Scraping 10 records...
#   📊 Page 63: Scraping 10 records...
#   📊 Page 64: Scraping 10 records...
#   📊 Page 65: Scraping 10 records...
#   📊 Page 66: Scraping 10 records...
#   📊 Page 67: Scraping 10 records...
#   📊 Page 68: Scraping 10 records...
#   📊 Page 69: Scraping 10 records...
#   📊 Page 70: Scraping 10 records...
#   📊 Page 71: Scraping 10 records...
#   📊 Page 72: Scraping 10 records...
#   📊 Page 73: Scraping 10 records...
#   📊 Page 74: Scraping 10 records...
#   📊 Page 75: Scraping 10 records...
#   📊 Page 76: Scraping 10 records...
#   📊 Page 77: Scraping 10 records...
#   📊 Page 78: Scraping 10 records...
#   📊 Page 79: Scraping 10 records...
#   📊 Page 80: Scraping 10 records...
#   📊 Page 81: Scraping 10 records...
#   📊 Page 82: Scraping 10 records...
#   📊 Page 83: Scraping 10 records...
#   📊 Page 84: Scraping 10 records...
#   📊 Page 85: Scraping 10 records...
#   📊 Page 86: Scraping 10 records...
#   📊 Page 87: Scraping 10 records...
#   📊 Page 88: Scraping 10 records...
#   📊 Page 89: Scraping 10 records...
#   📊 Page 90: Scraping 10 records...
#   📊 Page 91: Scraping 10 records...
#   📊 Page 92: Scraping 10 records...
#   📊 Page 93: Scraping 10 records...
#   📊 Page 94: Scraping 10 records...
#   📊 Page 95: Scraping 10 records...
#   📊 Page 96: Scraping 10 records...
#   📊 Page 97: Scraping 10 records...
#   📊 Page 98: Scraping 10 records...
#   📊 Page 99: Scraping 10 records...
#   📊 Page 100: Scraping 10 records...
#   📊 Page 101: Scraping 10 records...
#   📊 Page 102: Scraping 10 records...
#   📊 Page 103: Scraping 10 records...
#   📊 Page 104: Scraping 10 records...
#   📊 Page 105: Scraping 10 records...
#   📊 Page 106: Scraping 10 records...
#   📊 Page 107: Scraping 10 records...
#   📊 Page 108: Scraping 10 records...
#   📊 Page 109: Scraping 10 records...
#   📊 Page 110: Scraping 10 records...
#   📊 Page 111: Scraping 10 records...
#   📊 Page 112: Scraping 10 records...
#   📊 Page 113: Scraping 10 records...
#   📊 Page 114: Scraping 10 records...
#   📊 Page 115: Scraping 10 records...
#   📊 Page 116: Scraping 10 records...
#   📊 Page 117: Scraping 10 records...
#   📊 Page 118: Scraping 10 records...
#   📊 Page 119: Scraping 10 records...
#   📊 Page 120: Scraping 10 records...
#   📊 Page 121: Scraping 10 records...
#   📊 Page 122: Scraping 10 records...
#   📊 Page 123: Scraping 10 records...
#   📊 Page 124: Scraping 10 records...
#   📊 Page 125: Scraping 10 records...
#   📊 Page 126: Scraping 10 records...
#   📊 Page 127: Scraping 10 records...
#   📊 Page 128: Scraping 10 records...
#   📊 Page 129: Scraping 10 records...
#   📊 Page 130: Scraping 10 records...
#   📊 Page 131: Scraping 10 records...
#   📊 Page 132: Scraping 10 records...
#   📊 Page 133: Scraping 10 records...
#   📊 Page 134: Scraping 10 records...
#   📊 Page 135: Scraping 10 records...
#   📊 Page 136: Scraping 10 records...
#   📊 Page 137: Scraping 10 records...
#   📊 Page 138: Scraping 10 records...
#   📊 Page 139: Scraping 10 records...
#   📊 Page 140: Scraping 10 records...
#   📊 Page 141: Scraping 10 records...
#   📊 Page 142: Scraping 10 records...
#   📊 Page 143: Scraping 10 records...
#   📊 Page 144: Scraping 10 records...
#   📊 Page 145: Scraping 10 records...
#   📊 Page 146: Scraping 10 records...
#   📊 Page 147: Scraping 10 records...
#   📊 Page 148: Scraping 10 records...
#   📊 Page 149: Scraping 10 records...
#   📊 Page 150: Scraping 10 records...
#   📊 Page 151: Scraping 10 records...
#   📊 Page 152: Scraping 10 records...
#   📊 Page 153: Scraping 10 records...
#   📊 Page 154: Scraping 10 records...
#   📊 Page 155: Scraping 10 records...
#   📊 Page 156: Scraping 10 records...
#   📊 Page 157: Scraping 10 records...
#   📊 Page 158: Scraping 10 records...
#   📊 Page 159: Scraping 10 records...
#   📊 Page 160: Scraping 10 records...
#   📊 Page 161: Scraping 10 records...
#   📊 Page 162: Scraping 10 records...
#   📊 Page 163: Scraping 10 records...
#   📊 Page 164: Scraping 10 records...
#   📊 Page 165: Scraping 10 records...
#   📊 Page 166: Scraping 10 records...
#   📊 Page 167: Scraping 10 records...
#   📊 Page 168: Scraping 10 records...
#   📊 Page 169: Scraping 10 records...
#   📊 Page 170: Scraping 10 records...
#   📊 Page 171: Scraping 10 records...
#   📊 Page 172: Scraping 10 records...
#   📊 Page 173: Scraping 10 records...
#   📊 Page 174: Scraping 10 records...
#   📊 Page 175: Scraping 10 records...
#   📊 Page 176: Scraping 10 records...
#   📊 Page 177: Scraping 10 records...
#   📊 Page 178: Scraping 10 records...
#   📊 Page 179: Scraping 10 records...
#   📊 Page 180: Scraping 10 records...
#   📊 Page 181: Scraping 10 records...
#   📊 Page 182: Scraping 10 records...
#   📊 Page 183: Scraping 10 records...
#   📊 Page 184: Scraping 10 records...
#   📊 Page 185: Scraping 10 records...
#   📊 Page 186: Scraping 10 records...
#   📊 Page 187: Scraping 10 records...
#   📊 Page 188: Scraping 10 records...
#   📊 Page 189: Scraping 10 records...
#   📊 Page 190: Scraping 10 records...
#   📊 Page 191: Scraping 10 records...
#   📊 Page 192: Scraping 10 records...
#   📊 Page 193: Scraping 10 records...
#   📊 Page 194: Scraping 10 records...
#   📊 Page 195: Scraping 10 records...
#   📊 Page 196: Scraping 10 records...
#   📊 Page 197: Scraping 10 records...
#   📊 Page 198: Scraping 10 records...
#   📊 Page 199: Scraping 10 records...
#   📊 Page 200: Scraping 10 records...
#   📊 Page 201: Scraping 10 records...
#   📊 Page 202: Scraping 10 records...
#   📊 Page 203: Scraping 10 records...
#   📊 Page 204: Scraping 10 records...
#   📊 Page 205: Scraping 10 records...
#   📊 Page 206: Scraping 10 records...
#   📊 Page 207: Scraping 10 records...
#   📊 Page 208: Scraping 10 records...
#   📊 Page 209: Scraping 10 records...
#   📊 Page 210: Scraping 10 records...
#   📊 Page 211: Scraping 10 records...
#   📊 Page 212: Scraping 10 records...
#   📊 Page 213: Scraping 10 records...
#   📊 Page 214: Scraping 10 records...
#   📊 Page 215: Scraping 10 records...
#   📊 Page 216: Scraping 10 records...
#   📊 Page 217: Scraping 10 records...
#   📊 Page 218: Scraping 10 records...
#   📊 Page 219: Scraping 10 records...
#   📊 Page 220: Scraping 10 records...
#   📊 Page 221: Scraping 10 records...
#   📊 Page 222: Scraping 10 records...
#   📊 Page 223: Scraping 10 records...
#   📊 Page 224: Scraping 10 records...
#   📊 Page 225: Scraping 10 records...
#   📊 Page 226: Scraping 10 records...
#   📊 Page 227: Scraping 10 records...
#   📊 Page 228: Scraping 10 records...
#   📊 Page 229: Scraping 10 records...
#   📊 Page 230: Scraping 10 records...
#   📊 Page 231: Scraping 10 records...
#   📊 Page 232: Scraping 10 records...
#   📊 Page 233: Scraping 10 records...
#   📊 Page 234: Scraping 10 records...
#   📊 Page 235: Scraping 10 records...
#   📊 Page 236: Scraping 10 records...
#   📊 Page 237: Scraping 10 records...
#   📊 Page 238: Scraping 10 records...
#   📊 Page 239: Scraping 10 records...
#   📊 Page 240: Scraping 10 records...
#   📊 Page 241: Scraping 10 records...
#   📊 Page 242: Scraping 10 records...
#   📊 Page 243: Scraping 10 records...
#   📊 Page 244: Scraping 10 records...
#   📊 Page 245: Scraping 10 records...
#   📊 Page 246: Scraping 10 records...
#   📊 Page 247: Scraping 10 records...
#   📊 Page 248: Scraping 10 records...
#   📊 Page 249: Scraping 10 records...
#   📊 Page 250: Scraping 10 records...
#   📊 Page 251: Scraping 10 records...
#   📊 Page 252: Scraping 10 records...
#   📊 Page 253: Scraping 10 records...
#   📊 Page 254: Scraping 10 records...
#   📊 Page 255: Scraping 10 records...
#   📊 Page 256: Scraping 10 records...
#   📊 Page 257: Scraping 10 records...
#   📊 Page 258: Scraping 10 records...
#   📊 Page 259: Scraping 10 records...
#   📊 Page 260: Scraping 10 records...
#   📊 Page 261: Scraping 10 records...
#   📊 Page 262: Scraping 10 records...
#   📊 Page 263: Scraping 10 records...
#   📊 Page 264: Scraping 10 records...
#   📊 Page 265: Scraping 10 records...
#   📊 Page 266: Scraping 10 records...
#   📊 Page 267: Scraping 10 records...
#   📊 Page 268: Scraping 10 records...
#   📊 Page 269: Scraping 10 records...
#   📊 Page 270: Scraping 10 records...
#   📊 Page 271: Scraping 10 records...
#   📊 Page 272: Scraping 10 records...
#   📊 Page 273: Scraping 10 records...
#   📊 Page 274: Scraping 10 records...
#   📊 Page 275: Scraping 10 records...
#   📊 Page 276: Scraping 10 records...
#   📊 Page 277: Scraping 10 records...
#   📊 Page 278: Scraping 10 records...
#   📊 Page 279: Scraping 10 records...
#   📊 Page 280: Scraping 10 records...
#   📊 Page 281: Scraping 10 records...
#   📊 Page 282: Scraping 10 records...
#   📊 Page 283: Scraping 10 records...
#   📊 Page 284: Scraping 10 records...
#   📊 Page 285: Scraping 10 records...
#   📊 Page 286: Scraping 10 records...
#   📊 Page 287: Scraping 10 records...
#   📊 Page 288: Scraping 10 records...
#   📊 Page 289: Scraping 10 records...
#   📊 Page 290: Scraping 10 records...
#   📊 Page 291: Scraping 10 records...
#   📊 Page 292: Scraping 10 records...
#   📊 Page 293: Scraping 10 records...
#   📊 Page 294: Scraping 10 records...
#   📊 Page 295: Scraping 10 records...
#   📊 Page 296: Scraping 10 records...
#   📊 Page 297: Scraping 10 records...
#   📊 Page 298: Scraping 10 records...
#   📊 Page 299: Scraping 10 records...
#   📊 Page 300: Scraping 10 records...
#   📊 Page 301: Scraping 10 records...
#   📊 Page 302: Scraping 10 records...
#   📊 Page 303: Scraping 10 records...
#   📊 Page 304: Scraping 10 records...
#   📊 Page 305: Scraping 10 records...
#   📊 Page 306: Scraping 10 records...
#   📊 Page 307: Scraping 10 records...
#   📊 Page 308: Scraping 10 records...
#   📊 Page 309: Scraping 10 records...
#   📊 Page 310: Scraping 10 records...
#   📊 Page 311: Scraping 10 records...
#   📊 Page 312: Scraping 10 records...
#   📊 Page 313: Scraping 10 records...
#   📊 Page 314: Scraping 10 records...
#   📊 Page 315: Scraping 10 records...
#   📊 Page 316: Scraping 10 records...
#   📊 Page 317: Scraping 10 records...
#   📊 Page 318: Scraping 10 records...
#   📊 Page 319: Scraping 10 records...
#   📊 Page 320: Scraping 10 records...
#   📊 Page 321: Scraping 10 records...
#   📊 Page 322: Scraping 10 records...
#   📊 Page 323: Scraping 10 records...
#   📊 Page 324: Scraping 10 records...
#   📊 Page 325: Scraping 10 records...
#   📊 Page 326: Scraping 10 records...
#   📊 Page 327: Scraping 10 records...
#   📊 Page 328: Scraping 10 records...
#   📊 Page 329: Scraping 10 records...
#   📊 Page 330: Scraping 10 records...
#   📊 Page 331: Scraping 10 records...
#   📊 Page 332: Scraping 10 records...
#   📊 Page 333: Scraping 10 records...
#   📊 Page 334: Scraping 10 records...
#   📊 Page 335: Scraping 10 records...
#   📊 Page 336: Scraping 10 records...
#   📊 Page 337: Scraping 10 records...
#   📊 Page 338: Scraping 10 records...
#   📊 Page 339: Scraping 10 records...
#   📊 Page 340: Scraping 10 records...
#   📊 Page 341: Scraping 10 records...
#   📊 Page 342: Scraping 10 records...
#   📊 Page 343: Scraping 10 records...
#   📊 Page 344: Scraping 10 records...
#   📊 Page 345: Scraping 10 records...
#   📊 Page 346: Scraping 10 records...
#   📊 Page 347: Scraping 10 records...
#   📊 Page 348: Scraping 10 records...
#   📊 Page 349: Scraping 10 records...
#   📊 Page 350: Scraping 10 records...
#   📊 Page 351: Scraping 10 records...
#   📊 Page 352: Scraping 10 records...
#   📊 Page 353: Scraping 10 records...
#   📊 Page 354: Scraping 10 records...
#   📊 Page 355: Scraping 10 records...
#   📊 Page 356: Scraping 10 records...
#   📊 Page 357: Scraping 10 records...
#   📊 Page 358: Scraping 10 records...
#   📊 Page 359: Scraping 10 records...
#   📊 Page 360: Scraping 10 records...
#   📊 Page 361: Scraping 10 records...
#   📊 Page 362: Scraping 10 records...
#   📊 Page 363: Scraping 10 records...
#   📊 Page 364: Scraping 10 records...
#   📊 Page 365: Scraping 10 records...
#   📊 Page 366: Scraping 10 records...
#   📊 Page 367: Scraping 6 records...
#   🎉 Reached final page (367) for Activity 1.
#   └── ⚙️ Searching Activity ID: 7 (1(e) Nuclear power projects an...)
#   ℹ️ No results found for State: 33 + Activity: 7. Proceeding...
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 3.
#   └── ⚙️ Searching Activity ID: 79 (2(c) Pellet Plant...)
#   ℹ️ No results found for State: 33 + Activity: 79. Proceeding...
#   └── ⚙️ Searching Activity ID: 20 (5(b) Pesticides industry and p...)
#   ℹ️ No results found for State: 33 + Activity: 20. Proceeding...
#   └── ⚙️ Searching Activity ID: 21 (5(c) Petro-chemical complexes ...)
#   ℹ️ No results found for State: 33 + Activity: 21. Proceeding...
#   └── ⚙️ Searching Activity ID: 23 (5(e ) Petroleum products and p...)
#   ℹ️ No results found for State: 33 + Activity: 23. Proceeding...
#   └── ⚙️ Searching Activity ID: 12 (4(a) Petroleum refining indust...)
#   ℹ️ No results found for State: 33 + Activity: 12. Proceeding...
#   └── ⚙️ Searching Activity ID: 2 (6(a) Pipelines...)
#   ℹ️ No results found for State: 33 + Activity: 2. Proceeding...
#   └── ⚙️ Searching Activity ID: 35 (7(e) Ports, harbors, breakwate...)
#   📊 Page 1: Scraping 8 records...
#   🎉 Reached final page (1) for Activity 35.
#   └── ⚙️ Searching Activity ID: 27 (5(i) Pulp & Paper Industry...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 27.
#   └── ⚙️ Searching Activity ID: 5 (1(c) River Valley/Irrigation p...)
#   📊 Page 1: Scraping 8 records...
#   🎉 Reached final page (1) for Activity 5.
#   └── ⚙️ Searching Activity ID: 36 (7(f) Road...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 36.
#   └── ⚙️ Searching Activity ID: 30 (7(b) Ship breaking yards inclu...)
#   ℹ️ No results found for State: 33 + Activity: 30. Proceeding...
#   └── ⚙️ Searching Activity ID: 18 (4(f) Skin/hide processing incl...)
#   ℹ️ No results found for State: 33 + Activity: 18. Proceeding...
#   └── ⚙️ Searching Activity ID: 77 (1(a)(ii) Slurry pipelines pass...)
#   ℹ️ No results found for State: 33 + Activity: 77. Proceeding...
#   └── ⚙️ Searching Activity ID: 17 (4(e) Soda ash Industry...)
#   ℹ️ No results found for State: 33 + Activity: 17. Proceeding...
#   └── ⚙️ Searching Activity ID: 28 (5(j) Sugar Industry...)
#   ℹ️ No results found for State: 33 + Activity: 28. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 6 records...
#   🎉 Reached final page (5) for Activity 24.
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   📊 Page 1: Scraping 6 records...
#   🎉 Reached final page (1) for Activity 6.
#   └── ⚙️ Searching Activity ID: 40 (8(b) Townships/ Area Developme...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 10 records...
#   📊 Page 6: Scraping 10 records...
#   📊 Page 7: Scraping 10 records...
#   📊 Page 8: Scraping 10 records...
#   📊 Page 9: Scraping 10 records...
#   📊 Page 10: Scraping 10 records...
#   📊 Page 11: Scraping 10 records...
#   📊 Page 12: Scraping 10 records...
#   📊 Page 13: Scraping 10 records...
#   📊 Page 14: Scraping 10 records...
#   📊 Page 15: Scraping 10 records...
#   📊 Page 16: Scraping 10 records...
#   📊 Page 17: Scraping 10 records...
#   📊 Page 18: Scraping 10 records...
#   📊 Page 19: Scraping 10 records...
#   📊 Page 20: Scraping 10 records...
#   📊 Page 21: Scraping 10 records...
#   📊 Page 22: Scraping 10 records...
#   📊 Page 23: Scraping 10 records...
#   📊 Page 24: Scraping 10 records...
#   📊 Page 25: Scraping 10 records...
#   📊 Page 26: Scraping 10 records...
#   📊 Page 27: Scraping 10 records...
#   📊 Page 28: Scraping 10 records...
#   📊 Page 29: Scraping 5 records...
#   🎉 Reached final page (29) for Activity 40.
#
# --- Final Extracted Dataset Preview ---
#   S. No.               Proposal No.  \
# 0      1  SIA/TN/INFRA2/581685/2026
# 1      2  SIA/TN/INFRA2/469624/2024
# 2      1  SIA/TN/INFRA2/583067/2026
# 3      2  SIA/TN/INFRA2/573451/2026
# 4      3  SIA/TN/INFRA2/553911/2025
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for Amendment in E...
# 2  Clearance Type: Application for amendment in T...
# 3  Clearance Type: Application for ToR (Category ...
# 4  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name    Location  \
# 0  Proposed Extension of Runway with Blast Pad, P...  TAMIL NADU
# 1  Modernization of Chennai Airport (Phase-II), C...  TAMIL NADU
# 2  Proposed Common Bio-Medical Waste Treatment Fa...  TAMIL NADU
# 3  Proposed Common Bio-Medical Waste Treatment Fa...  TAMIL NADU
# 4  Proposed Common Bio - Medical Waste Treatment ...  TAMIL NADU
#
#                                 Project Proponent Issuing Authority  \
# 0                     airports authority of india             SEIAA
# 1                     AIRPORTS AUTHORITY OF INDIA             SEIAA
# 2          RAMNAD DOCTORS ASSOCIATION – BMW PLANT             SEIAA
# 3                        SAGA ECO PRIVATE LIMITED             SEIAA
# 4  re sustainability healthcare solutions limited             SEIAA
#
#                           Proposal Status  State_Name  \
# 0                     Pending at MS SEIAA  TAMIL NADU
# 1                              EC Granted  TAMIL NADU
# 2  Proposal Accepted and Referred to SEAC  TAMIL NADU
# 3                             ToR Granted  TAMIL NADU
# 4                             ToR Granted  TAMIL NADU
#
#                            Activity Description
# 0                                 7(a) Airports
# 1                                 7(a) Airports
# 2  7(da) Bio-Medical Waste Treatment Facilities
# 3  7(da) Bio-Medical Waste Treatment Facilities
# 4  7(da) Bio-Medical Waste Treatment Facilities
#
# ✅ Total 4900 rows scraped and saved to F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\SEIAA_TN.xlsx
