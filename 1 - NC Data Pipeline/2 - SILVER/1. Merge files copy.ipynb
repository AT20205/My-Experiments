# %%
from datetime import datetime
import glob
import os
from dotenv import load_dotenv
import pandas as pd

load_dotenv()


# Define input (Silver) and output (Bronze) directory paths


# silver_dir = os.getenv("SILVERALL")
bronze_dir = os.getenv("BRONZENEW")
silver_dir = os.getenv("SILVER")

# Update silver_dir to include a subfolder named with the current date (e.g., YYYY-MM-DD or YYYYMMDD)
current_date_folder = datetime.now().strftime("%Y-%m-%d")
bronze_dir = os.path.join(bronze_dir, current_date_folder)

# Create Bronze directory if it doesn't already exist
if not os.path.exists(silver_dir):
    os.makedirs(silver_dir)
    print(f"Created directory: {silver_dir}")

# Find all Excel and CSV files inside the Silver folder
file_patterns = [
    os.path.join(bronze_dir, "*.xlsx"),
    os.path.join(bronze_dir, "*.xls"),
    os.path.join(bronze_dir, "*.csv"),
]

all_files = []
for pattern in file_patterns:
    all_files.extend(glob.glob(pattern))

print(f"Found {len(all_files)} file(s) in Silver layer:")
for f in all_files:
    print(f" - {os.path.basename(f)}")

if not all_files:
    print("\n❌ No matching Excel or CSV files were found in the Silver folder.")
else:
    dataframes = []

    # Read each file and append to our list
    for file_path in all_files:
        try:
            filename = os.path.basename(file_path)
            if file_path.endswith(".csv"):
                df = pd.read_csv(file_path)
            else:
                df = pd.read_excel(file_path)

            # --- Drop existing S. No. columns if present ---
            sno_variations = [
                "S. No.",
                "S.No.",
                "S.No",
                "S. No",
                "SNo",
                "S_No",
                "s.no.",
                "s.no",
            ]
            cols_to_drop = [
                col for col in df.columns if str(col).strip() in sno_variations
            ]
            if cols_to_drop:
                df.drop(columns=cols_to_drop, inplace=True)

            # Optionally add a metadata column tracking the source filename
            df["Source_File"] = filename

            dataframes.append(df)
            print(f"✓ Successfully loaded: {filename} ({len(df)} rows)")
        except Exception as e:
            print(f"❌ Error reading {os.path.basename(file_path)}: {e}")

    # Merge/Concatenate all DataFrames into one
    if dataframes:
        merged_df = pd.concat(dataframes, ignore_index=True)

        # --- Generate new continuous S. No. column ---
        merged_df.insert(0, "S. No.", range(1, len(merged_df) + 1))

        # Define output destination file path
        timestamp = datetime.now().strftime("%Y%m%d")
        output_file_path = os.path.join(silver_dir, f"{timestamp}.xlsx")

        # Save merged dataframe to Excel
        merged_df.to_excel(output_file_path, index=False)
        print(f"\n✅ Merge complete! Total combined rows: {len(merged_df)}")
        print(f"📁 Output file created at:\n   {output_file_path}")
    else:
        print("\n❌ Failed to parse any data from the identified files.")
# Out:
# Found 31 file(s) in Silver layer:
#  - MOEFCC_20260731_215153.xlsx
#  - SEIAA_ANDAMAN_AND_NICOBAR_ISLANDS_20260731_210714.xlsx
#  - SEIAA_ANDHRA_PRADESH_20260731_203331.xlsx
#  - SEIAA_ARUNACHAL_PRADESH_20260731_210538.xlsx
#  - SEIAA_ASSAM_20260731_211003.xlsx
#  - SEIAA_BIHAR_20260731_204730.xlsx
#  - SEIAA_CHHATTISGARH_20260731_203718.xlsx
#  - SEIAA_DELHI_20260731_210928.xlsx
#  - SEIAA_GOA_20260731_205908.xlsx
#  - SEIAA_GUJARAT_20260731_204106.xlsx
#  - SEIAA_HARYANA_20260731_205540.xlsx
#  - SEIAA_HIMACHAL_PRADESH_20260731_204512.xlsx
#  - SEIAA_JAMMU_AND_KASHMIR_20260731_204833.xlsx
#  - SEIAA_JHARKHAND_20260731_210246.xlsx
#  - SEIAA_KARNATAKA_20260731_204531.xlsx
#  - SEIAA_KERALA_20260731_212302.xlsx
#  - SEIAA_MADHYA_PRADESH_20260731_204545.xlsx
#  - SEIAA_MAHARASHTRA_20260731_204520.xlsx
#  - SEIAA_MANIPUR_20260731_210956.xlsx
#  - SEIAA_MEGHALAYA_20260731_205048.xlsx
#  - SEIAA_ODISHA_20260731_204128.xlsx
#  - SEIAA_PUDUCHERRY_20260731_210145.xlsx
#  - SEIAA_PUNJAB_20260731_204053.xlsx
#  - SEIAA_RAJASTHAN_20260731_211407.xlsx
#  - SEIAA_TAMIL_NADU_20260731_204820.xlsx
#  - SEIAA_TELANGANA_20260731_205453.xlsx
#  - SEIAA_THE_DADRA_AND_NAGAR_HAVELI_AND_DAMAN_AND_DIU_20260731_210343.xlsx
#  - SEIAA_TRIPURA_20260731_205702.xlsx
#  - SEIAA_UTTARAKHAND_20260731_203215.xlsx
#  - SEIAA_UTTAR_PRADESH_20260731_204725.xlsx
#  - SEIAA_WEST_BENGAL_20260731_211724.xlsx
# ✓ Successfully loaded: MOEFCC_20260731_215153.xlsx (1317 rows)
# ✓ Successfully loaded: SEIAA_ANDAMAN_AND_NICOBAR_ISLANDS_20260731_210714.xlsx (1 rows)
# ✓ Successfully loaded: SEIAA_ANDHRA_PRADESH_20260731_203331.xlsx (690 rows)
# ✓ Successfully loaded: SEIAA_ARUNACHAL_PRADESH_20260731_210538.xlsx (3 rows)
# ✓ Successfully loaded: SEIAA_ASSAM_20260731_211003.xlsx (170 rows)
# ✓ Successfully loaded: SEIAA_BIHAR_20260731_204730.xlsx (998 rows)
# ✓ Successfully loaded: SEIAA_CHHATTISGARH_20260731_203718.xlsx (409 rows)
# ✓ Successfully loaded: SEIAA_DELHI_20260731_210928.xlsx (1 rows)
# ✓ Successfully loaded: SEIAA_GOA_20260731_205908.xlsx (13 rows)
# ✓ Successfully loaded: SEIAA_GUJARAT_20260731_204106.xlsx (862 rows)
# ✓ Successfully loaded: SEIAA_HARYANA_20260731_205540.xlsx (37 rows)
# ✓ Successfully loaded: SEIAA_HIMACHAL_PRADESH_20260731_204512.xlsx (132 rows)
# ✓ Successfully loaded: SEIAA_JAMMU_AND_KASHMIR_20260731_204833.xlsx (77 rows)
# ✓ Successfully loaded: SEIAA_JHARKHAND_20260731_210246.xlsx (203 rows)
# ✓ Successfully loaded: SEIAA_KARNATAKA_20260731_204531.xlsx (699 rows)
# ✓ Successfully loaded: SEIAA_KERALA_20260731_212302.xlsx (304 rows)
# ✓ Successfully loaded: SEIAA_MADHYA_PRADESH_20260731_204545.xlsx (932 rows)
# ✓ Successfully loaded: SEIAA_MAHARASHTRA_20260731_204520.xlsx (947 rows)
# ✓ Successfully loaded: SEIAA_MANIPUR_20260731_210956.xlsx (3 rows)
# ✓ Successfully loaded: SEIAA_MEGHALAYA_20260731_205048.xlsx (57 rows)
# ✓ Successfully loaded: SEIAA_ODISHA_20260731_204128.xlsx (438 rows)
# ✓ Successfully loaded: SEIAA_PUDUCHERRY_20260731_210145.xlsx (2 rows)
# ✓ Successfully loaded: SEIAA_PUNJAB_20260731_204053.xlsx (128 rows)
# ✓ Successfully loaded: SEIAA_RAJASTHAN_20260731_211407.xlsx (2604 rows)
# ✓ Successfully loaded: SEIAA_TAMIL_NADU_20260731_204820.xlsx (597 rows)
# ✓ Successfully loaded: SEIAA_TELANGANA_20260731_205453.xlsx (299 rows)
# ✓ Successfully loaded: SEIAA_THE_DADRA_AND_NAGAR_HAVELI_AND_DAMAN_AND_DIU_20260731_210343.xlsx (2 rows)
# ✓ Successfully loaded: SEIAA_TRIPURA_20260731_205702.xlsx (11 rows)
# ✓ Successfully loaded: SEIAA_UTTARAKHAND_20260731_203215.xlsx (2 rows)
# ✓ Successfully loaded: SEIAA_UTTAR_PRADESH_20260731_204725.xlsx (509 rows)
# ✓ Successfully loaded: SEIAA_WEST_BENGAL_20260731_211724.xlsx (148 rows)
#
# ✅ Merge complete! Total combined rows: 12595
# 📁 Output file created at:
#    F:\Chimney Work\Marketing\LeadGen\Data Architecture\2 - SILVER\New Pulls\20260731.xlsx
