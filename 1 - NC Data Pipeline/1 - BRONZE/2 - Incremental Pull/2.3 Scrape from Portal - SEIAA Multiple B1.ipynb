# %%
# %load_ext autoreload
# %autoreload 2

import os
import re
import pandas as pd
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import your scraper function from the .py file
from scraper_utils import run_scraper

# Define parameters dynamically at runtime
path = os.getenv("PORTAL")
BRONZE = os.getenv("BRONZENEW")

states_input = {
    "10": "BIHAR", 
    "36": "TELANGANA", 
    "20": "JHARKHAND", 
    "18": "ASSAM", 
    "19": "WEST BENGAL",
    "32": "KERALA"

}

# --- DYNAMIC ACTIVITIES_INPUT GENERATION & STATE ITERATION START ---
stact_path = os.getenv("STACT")
if not stact_path:
    raise ValueError("⚠️ STACT environment variable is not set.")

if not stact_path.lower().endswith((".xlsx", ".xls")):
    stact_path += ".xlsx"

if not os.path.exists(stact_path):
    raise FileNotFoundError(f"⚠️ STACT file not found at: {stact_path}")

# Read the STACT Excel file once
stact_df = pd.read_excel(stact_path)

# Standardize Location values in Excel for comparison
stact_df["_location_clean"] = (
    stact_df["Location"].astype(str).str.strip().str.upper()
)

# Regex to extract key and value from strings like: "15": "4(c) Asbestos milling...",
mapping_pattern = re.compile(r'^\s*"(.*?)":\s*"(.*?)"\s*,\s*$')

# Iterate over each state individually to optimize execution per state
for state_code, state_name in states_input.items():
    current_state_input = {state_code: state_name}
    target_state_clean = state_name.strip().upper()
    
    print(f"\n==================================================")
    print(f"🔄 Processing State: {state_name} (Code: {state_code})")
    print(f"==================================================")

    # Filter rows for the current state only
    matching_rows = stact_df[
        stact_df["_location_clean"] == target_state_clean
    ]

    # DEFENSIVE CHECK 1: Identify if State is Missing in STACT Excel
    if matching_rows.empty:
        print(f"⚠️ WARNING: State '{state_name}' from states_input was NOT found in the STACT Excel file. Skipping...")
        continue

    activities_input = {}
    unique_mappings = matching_rows["Activity Mapping"].dropna().unique()

    for entry in unique_mappings:
        entry_str = str(entry).strip()
        match = mapping_pattern.match(entry_str)
        if match:
            act_id, act_desc = match.groups()
            
            clean_act_id = act_id.strip()
            clean_act_desc = re.sub(r"\s+", " ", act_desc).strip()

            if clean_act_id not in activities_input:
                activities_input[clean_act_id] = clean_act_desc

    # DEFENSIVE CHECK 2: Ensure At Least One Activity Was Found
    if not activities_input:
        print(f"⚠️ WARNING: No valid activities found in STACT Excel for state '{state_name}'. Skipping...")
        continue

    print(f"✅ Loaded {len(activities_input)} unique activity/activities for '{state_name}':")
    for k, v in activities_input.items():
        print(f'   "{k}": "{v}"')

    # Run execution specifically for this state and its corresponding activities
    run_scraper(
        portal_url=path,
        output_base_dir=BRONZE,
        states=current_state_input,
        activities=activities_input,
        year="2026",
        headless=False  # Set to True if you don't want the browser window to open
    )
# --- DYNAMIC ACTIVITIES_INPUT GENERATION & STATE ITERATION END ---
# Out:
# ==================================================
# 🔄 Processing State: BIHAR (Code: 10)
# ==================================================
# ✅ Loaded 8 unique activity/activities for 'BIHAR':
#    "6": "1(d) Thermal Power Plants"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "11": "3(b) Cement plants"
#    "15": "4(c) Asbestos milling / asbestos-based products"
#    "19": "5(a) Chemical fertilizers"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "28": "5(j) Sugar Industry"
#
# 🌍 Processing State: BIHAR (Value: 10)...
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ⚠️ Attempt 1 failed due to loading delay: Message: stale element reference: stale element not found in the current frame
#   (Session info: chrome=151.0.7922.108); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#staleelementreferenceexception
# Stacktrace:
# 	chromedriver!GetHandleVerifier [0x7ff7ead68935+14ce5]
# 	chromedriver!GetHandleVerifier [0x7ff7ead68990+14d40]
# 	chromedriver!(No symbol) [0x7ff7ea895afd]
# 	chromedriver!(No symbol) [0x7ff7ea89da61]
# 	chromedriver!(No symbol) [0x7ff7ea8a0a15]
# 	chromedriver!(No symbol) [0x7ff7ea8a0adf]
# 	chromedriver!(No symbol) [0x7ff7ea8ec5bb]
# 	chromedriver!(No symbol) [0x7ff7ea9195ba]
# 	chromedriver!(No symbol) [0x7ff7ea8e4836]
# 	chromedriver!(No symbol) [0x7ff7ea93e4ab]
# 	chromedriver!(No symbol) [0x7ff7ea8e308c]
# 	chromedriver!(No symbol) [0x7ff7ea8e3fb3]
# 	chromedriver!GetHandleVerifier [0x7ff7eb39e5fb+64a9ab]
# 	chromedriver!GetHandleVerifier [0x7ff7eb398b02+644eb2]
# 	chromedriver!GetHandleVerifier [0x7ff7eb3be39e+66a74e]
# 	chromedriver!GetHandleVerifier [0x7ff7ead85d6e+3211e]
# 	chromedriver!GetHandleVerifier [0x7ff7ead8e51c+3a8cc]
# 	chromedriver!GetHandleVerifier [0x7ff7ead72844+1ebf4]
# 	chromedriver!GetHandleVerifier [0x7ff7ead729d4+1ed84]
# 	chromedriver!GetHandleVerifier [0x7ff7ead55d07+20b7]
# 	KERNEL32!BaseThreadInitThunk [0x7ffd37adccb7+17]
# 	ntdll!RtlUserThreadStart [0x7ffd39dead6c+2c]
# . Retrying...
#   ℹ️ No results found for State: 10 + Activity: 6. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 10 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   📊 Page 1: Scraping 3 records...
#   🎉 Reached final page (1) for Activity 11.
#   └── ⚙️ Searching Activity ID: 15 (4(c) Asbestos milling / asbest...)
#   ℹ️ No results found for State: 10 + Activity: 15. Proceeding...
#   └── ⚙️ Searching Activity ID: 19 (5(a) Chemical fertilizers...)
#   ℹ️ No results found for State: 10 + Activity: 19. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 25.
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 75.
#   └── ⚙️ Searching Activity ID: 28 (5(j) Sugar Industry...)
#   ℹ️ No results found for State: 10 + Activity: 28. Proceeding...
#
# --- Extracted Dataset Preview for BIHAR ---
#   S. No.             Proposal No.  \
# 0      1  SIA/BR/IND1/586920/2026
# 1      2  SIA/BR/IND1/573477/2026
# 2      3  SIA/BR/IND1/573531/2026
# 3      1  SIA/BR/IND2/570617/2026
# 4      2  SIA/BR/IND2/562992/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for EC (Category A...
# 1  Clearance Type: Application for EC (Category A...
# 2  Clearance Type: Application for ToR (Category ...
# 3  Clearance Type: Application for EC (Category A...
# 4  Clearance Type: Application for Amendment in E...
#
#                                         Project Name Location  \
# 0  Standalone Grinding Unit with Cement Productio...    BIHAR
# 1  Cement Grinding and Blending Unit of 0.12 Mill...    BIHAR
# 2  Standalone Grinding Unit with Cement Productio...    BIHAR
# 3  Greenfield Project of 175 KLPD grain based dis...    BIHAR
# 4  Vishnu Sugar Mills Ltd. (Molasse based Distill...    BIHAR
#
#                  Project Proponent Issuing Authority  \
# 0         UltraTech Cement Limited             SEIAA
# 1                     PRANAV KUMAR             SEIAA
# 2         UltraTech Cement Limited             SEIAA
# 3  GREENATHOL EBIZ PRIVATE LIMITED             SEIAA
# 4       VISHNU SUGAR MILLS LIMITED             SEIAA
#
#                           Proposal Status State_Name Activity Description
# 0  Proposal Accepted and Referred to SEAC      BIHAR   3(b) Cement plants
# 1                              EC Granted      BIHAR   3(b) Cement plants
# 2                             ToR Granted      BIHAR   3(b) Cement plants
# 3                              EC Granted      BIHAR    5(g) Distilleries
# 4                             EC Rejected      BIHAR    5(g) Distilleries
# ✅ Total 7 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-08-09\SEIAA_BIHAR_20260809.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: TELANGANA (Code: 36)
# ==================================================
# ✅ Loaded 9 unique activity/activities for 'TELANGANA':
#    "6": "1(d) Thermal Power Plants"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "11": "3(b) Cement plants"
#    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)"
#    "22": "5(d) Manmade fibers manufacturing"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "27": "5(i) Pulp & Paper Industry"
#
# 🌍 Processing State: TELANGANA (Value: 36)...
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ℹ️ No results found for State: 36 + Activity: 6. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 5 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   ℹ️ No results found for State: 36 + Activity: 11. Proceeding...
#   └── ⚙️ Searching Activity ID: 20 (5(b) Pesticides industry and p...)
#   ℹ️ No results found for State: 36 + Activity: 20. Proceeding...
#   └── ⚙️ Searching Activity ID: 22 (5(d) Manmade fibers manufactur...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 22.
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 8 records...
#   🎉 Reached final page (3) for Activity 24.
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 25.
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 75.
#   └── ⚙️ Searching Activity ID: 27 (5(i) Pulp & Paper Industry...)
#   ℹ️ No results found for State: 36 + Activity: 27. Proceeding...
#
# --- Extracted Dataset Preview for TELANGANA ---
#   S. No.             Proposal No.  \
# 0      1  SIA/TG/IND1/585442/2026
# 1      2  SIA/TG/IND1/580728/2026
# 2      3  SIA/TG/IND1/575721/2026
# 3      4  SIA/TG/IND1/569455/2026
# 4      5  SIA/TG/IND1/568942/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for ToR (Category ...
# 2  Clearance Type: Application for ToR (Category ...
# 3  Clearance Type: Application for Transfer of EC...
# 4  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name   Location  \
# 0   M/s. MAHA SHIV SHAKTI STEEL ROLLING MILL PVT LTD  TELANGANA
# 1                        M/s. Vinayak Steels Limited  TELANGANA
# 2          M/s. MS Agarwal Foundries Private Limited  TELANGANA
# 3  Transfer of existing Environmental Clearance f...  TELANGANA
# 4          M/s. MPL Steel Industries Private Limited  TELANGANA
#
#                       Project Proponent Issuing Authority  \
# 0                DHIRAJ KUMAR SONTHALIA             SEIAA
# 1                          VINOD SHARMA             SEIAA
# 2         MS AGARWAL FOUNDERIES PVT LTD             SEIAA
# 3                          pranay ispat             SEIAA
# 4  MPL STEEL INDUSTRIES PRIVATE LIMITED             SEIAA
#
#                          Proposal Status State_Name  \
# 0                     Under Verification  TELANGANA
# 1  DELISTED BY SYSTEM\n(at : 23/07/2026)  TELANGANA
# 2                   Standard ToR Granted  TELANGANA
# 3                             EC Granted  TELANGANA
# 4                             EC Granted  TELANGANA
#
#                                 Activity Description
# 0  3(a) Metallurgical Industries (ferrous and non...
# 1  3(a) Metallurgical Industries (ferrous and non...
# 2  3(a) Metallurgical Industries (ferrous and non...
# 3  3(a) Metallurgical Industries (ferrous and non...
# 4  3(a) Metallurgical Industries (ferrous and non...
# ✅ Total 38 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-08-09\SEIAA_TELANGANA_20260809.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: JHARKHAND (Code: 20)
# ==================================================
# ✅ Loaded 13 unique activity/activities for 'JHARKHAND':
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#    "6": "1(d) Thermal Power Plants"
#    "9": "2(b) Mineral beneficiation"
#    "79": "2(c) Pellet Plant"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "11": "3(b) Cement plants"
#    "13": "4(b) Coke oven plants"
#    "14": "4(b)(ii) Coaltar processing units"
#    "19": "5(a) Chemical fertilizers"
#    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#
# 🌍 Processing State: JHARKHAND (Value: 20)...
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   ℹ️ No results found for State: 20 + Activity: 3. Proceeding...
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ℹ️ No results found for State: 20 + Activity: 6. Proceeding...
#   └── ⚙️ Searching Activity ID: 9 (2(b) Mineral beneficiation...)
#   ℹ️ No results found for State: 20 + Activity: 9. Proceeding...
#   └── ⚙️ Searching Activity ID: 79 (2(c) Pellet Plant...)
#   ℹ️ No results found for State: 20 + Activity: 79. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 6 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   ℹ️ No results found for State: 20 + Activity: 11. Proceeding...
#   └── ⚙️ Searching Activity ID: 13 (4(b) Coke oven plants...)
#   ℹ️ No results found for State: 20 + Activity: 13. Proceeding...
#   └── ⚙️ Searching Activity ID: 14 (4(b)(ii) Coaltar processing un...)
#   ℹ️ No results found for State: 20 + Activity: 14. Proceeding...
#   └── ⚙️ Searching Activity ID: 19 (5(a) Chemical fertilizers...)
#   ℹ️ No results found for State: 20 + Activity: 19. Proceeding...
#   └── ⚙️ Searching Activity ID: 23 (5(e ) Petroleum products and p...)
#   ℹ️ No results found for State: 20 + Activity: 23. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 20 + Activity: 24. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   ℹ️ No results found for State: 20 + Activity: 25. Proceeding...
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 75.
#
# --- Extracted Dataset Preview for JHARKHAND ---
#   S. No.             Proposal No.  \
# 0      1  SIA/JH/IND1/521365/2026
# 1      2  SIA/JH/IND1/534425/2026
# 2      3  SIA/JH/IND1/580873/2026
# 3      4  SIA/JH/IND1/574101/2026
# 4      5  SIA/JH/IND1/569809/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for ToR (Category ...
# 2  Clearance Type: Application for Amendment in E...
# 3  Clearance Type: Application for ToR (Category ...
# 4  Clearance Type: Application for Amendment in E...
#
#                                         Project Name   Location  \
# 0  Proposal for 0.5 MTPA Electrical Steel Complex...  JHARKHAND
# 1  Expansion of Ingot/Billet Production from 16,8...  JHARKHAND
# 2  Expansion of existing plant of 36000 TPA M.S. ...  JHARKHAND
# 3  Proposed Expansion of Rolling Mill (from 90,00...  JHARKHAND
# 4  Establishment of Greenfield Plant for 10,00,00...  JHARKHAND
#
#                            Project Proponent Issuing Authority  \
# 0                         Tata Steel Limited             SEIAA
# 1     SRI LANGTA BABA STEELS PRIVATE LIMITED             SEIAA
# 2  JAI PRABHUJI IRON & STEEL PRIVATE LIMITED             SEIAA
# 3            SALUJA METALIKS Private limited             SEIAA
# 4                     BMW INDUSTRIES LIMITED             SEIAA
#
#                          Proposal Status State_Name  \
# 0                      Under Examination  JHARKHAND
# 1                             ADS Raised  JHARKHAND
# 2                             EC Granted  JHARKHAND
# 3  DELISTED BY SYSTEM\n(at : 14/06/2026)  JHARKHAND
# 4                             EC Granted  JHARKHAND
#
#                                 Activity Description
# 0  3(a) Metallurgical Industries (ferrous and non...
# 1  3(a) Metallurgical Industries (ferrous and non...
# 2  3(a) Metallurgical Industries (ferrous and non...
# 3  3(a) Metallurgical Industries (ferrous and non...
# 4  3(a) Metallurgical Industries (ferrous and non...
# ✅ Total 7 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-08-09\SEIAA_JHARKHAND_20260809.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: ASSAM (Code: 18)
# ==================================================
# ✅ Loaded 13 unique activity/activities for 'ASSAM':
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#    "6": "1(d) Thermal Power Plants"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "11": "3(b) Cement plants"
#    "12": "4(a) Petroleum refining industry"
#    "16": "4(d) Chlor-alkali industry"
#    "19": "5(a) Chemical fertilizers"
#    "21": "5(c) Petro-chemical complexes (industries based on processing of petroleum fractions"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "26": "5(h) Integrated paint industry"
#    "27": "5(i) Pulp & Paper Industry"
#
# 🌍 Processing State: ASSAM (Value: 18)...
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   📊 Page 1: Scraping 7 records...
#   🎉 Reached final page (1) for Activity 3.
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ℹ️ No results found for State: 18 + Activity: 6. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   📊 Page 1: Scraping 5 records...
#   🎉 Reached final page (1) for Activity 11.
#   └── ⚙️ Searching Activity ID: 12 (4(a) Petroleum refining indust...)
#   ℹ️ No results found for State: 18 + Activity: 12. Proceeding...
#   └── ⚙️ Searching Activity ID: 16 (4(d) Chlor-alkali industry...)
#   ℹ️ No results found for State: 18 + Activity: 16. Proceeding...
#   └── ⚙️ Searching Activity ID: 19 (5(a) Chemical fertilizers...)
#   ℹ️ No results found for State: 18 + Activity: 19. Proceeding...
#   └── ⚙️ Searching Activity ID: 21 (5(c) Petro-chemical complexes ...)
#   ℹ️ No results found for State: 18 + Activity: 21. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 18 + Activity: 24. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 25.
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   ℹ️ No results found for State: 18 + Activity: 75. Proceeding...
#   └── ⚙️ Searching Activity ID: 26 (5(h) Integrated paint industry...)
#   ℹ️ No results found for State: 18 + Activity: 26. Proceeding...
#   └── ⚙️ Searching Activity ID: 27 (5(i) Pulp & Paper Industry...)
#   ℹ️ No results found for State: 18 + Activity: 27. Proceeding...
#
# --- Extracted Dataset Preview for ASSAM ---
#   S. No.             Proposal No.  \
# 0      1  SIA/AS/IND2/546689/2026
# 1      2  SIA/AS/IND2/584805/2026
# 2      3  SIA/AS/IND2/515766/2026
# 3      4  SIA/AS/IND2/573032/2026
# 4      5  SIA/AS/IND2/570665/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for ToR (Category ...
# 2  Clearance Type: Application for ToR (Category ...
# 3  Clearance Type: Application for Validity Exten...
# 4  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name Location  \
# 0              Exploratory Drilling at Location. HZO    ASSAM
# 1  Environmental Clearance for the proposed well ...    ASSAM
# 2  Proposed Onshore Oil & Gas Exploration in OALP...    ASSAM
# 3  Proposed Workover Activities and Testing of Hy...    ASSAM
# 4  Application for Expansion (additional 3 Nos. o...    ASSAM
#
#                                Project Proponent Issuing Authority  \
# 0                              OIL INDIA LIMITED             SEIAA
# 1        OIL AND NATURAL GAS CORPORATION LIMITED             SEIAA
# 2                              OIL INDIA LIMITED             SEIAA
# 3                  OILMAX ENERGY PRIVATE LIMITED             SEIAA
# 4  M/s Vedanta Limited(Division Cairn Oil & Gas)             SEIAA
#
#       Proposal Status State_Name  \
# 0  Under Verification      ASSAM
# 1   Referred to SEIAA      ASSAM
# 2  Under Verification      ASSAM
# 3          EC Granted      ASSAM
# 4          EC Granted      ASSAM
#
#                                 Activity Description
# 0  1(b) Off-shore and onshore oil and gas explora...
# 1  1(b) Off-shore and onshore oil and gas explora...
# 2  1(b) Off-shore and onshore oil and gas explora...
# 3  1(b) Off-shore and onshore oil and gas explora...
# 4  1(b) Off-shore and onshore oil and gas explora...
# ✅ Total 16 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-08-09\SEIAA_ASSAM_20260809.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: WEST BENGAL (Code: 19)
# ==================================================
# ✅ Loaded 16 unique activity/activities for 'WEST BENGAL':
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#    "6": "1(d) Thermal Power Plants"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "11": "3(b) Cement plants"
#    "12": "4(a) Petroleum refining industry"
#    "13": "4(b) Coke oven plants"
#    "14": "4(b)(ii) Coaltar processing units"
#    "19": "5(a) Chemical fertilizers"
#    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)"
#    "21": "5(c) Petro-chemical complexes (industries based on processing of petroleum fractions"
#    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "26": "5(h) Integrated paint industry"
#    "27": "5(i) Pulp & Paper Industry"
#
# 🌍 Processing State: WEST BENGAL (Value: 19)...
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 3.
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ℹ️ No results found for State: 19 + Activity: 6. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 7 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 11.
#   └── ⚙️ Searching Activity ID: 12 (4(a) Petroleum refining indust...)
#   ℹ️ No results found for State: 19 + Activity: 12. Proceeding...
#   └── ⚙️ Searching Activity ID: 13 (4(b) Coke oven plants...)
#   ℹ️ No results found for State: 19 + Activity: 13. Proceeding...
#   └── ⚙️ Searching Activity ID: 14 (4(b)(ii) Coaltar processing un...)
#   ℹ️ No results found for State: 19 + Activity: 14. Proceeding...
#   └── ⚙️ Searching Activity ID: 19 (5(a) Chemical fertilizers...)
#   ℹ️ No results found for State: 19 + Activity: 19. Proceeding...
#   └── ⚙️ Searching Activity ID: 20 (5(b) Pesticides industry and p...)
#   ℹ️ No results found for State: 19 + Activity: 20. Proceeding...
#   └── ⚙️ Searching Activity ID: 21 (5(c) Petro-chemical complexes ...)
#   ℹ️ No results found for State: 19 + Activity: 21. Proceeding...
#   └── ⚙️ Searching Activity ID: 23 (5(e ) Petroleum products and p...)
#   ℹ️ No results found for State: 19 + Activity: 23. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   📊 Page 1: Scraping 8 records...
#   🎉 Reached final page (1) for Activity 24.
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   ℹ️ No results found for State: 19 + Activity: 25. Proceeding...
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   ℹ️ No results found for State: 19 + Activity: 75. Proceeding...
#   └── ⚙️ Searching Activity ID: 26 (5(h) Integrated paint industry...)
#   ℹ️ No results found for State: 19 + Activity: 26. Proceeding...
#   └── ⚙️ Searching Activity ID: 27 (5(i) Pulp & Paper Industry...)
#   ℹ️ No results found for State: 19 + Activity: 27. Proceeding...
#
# --- Extracted Dataset Preview for WEST BENGAL ---
#   S. No.             Proposal No.  \
# 0      1  SIA/WB/IND2/564066/2026
# 1      1  SIA/WB/IND1/579498/2026
# 2      2  SIA/WB/IND1/578999/2026
# 3      3  SIA/WB/IND1/578719/2026
# 4      4  SIA/WB/IND1/573287/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for amendment in T...
# 1  Clearance Type: Application for Corrigendum Fo...
# 2  Clearance Type: Application for Transfer of EC...
# 3  Clearance Type: Application for Corrigendum Fo...
# 4  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name     Location  \
# 0  Amendment of EC no. EC22B002WB155201 dated-26/...  WEST BENGAL
# 1  Proposed Upgradation & Expansion of Existing R...  WEST BENGAL
# 2  Transfer of Environment Clearance due to chang...  WEST BENGAL
# 3  Proposed corrigendum of EC vide EC Identificat...  WEST BENGAL
# 4  Environmental Clearance for the expansion of e...  WEST BENGAL
#
#                           Project Proponent Issuing Authority  \
# 0                             Champak Mitra             SEIAA
# 1                    BRAND ALLOYS PVT. LTD.             SEIAA
# 2            PRESTIGE STEEL PRIVATE LIMITED             SEIAA
# 3  CRESCENT FOUNDRY COMPANY PRIVATE LIMITED             SEIAA
# 4             SHREE RAMDOOT ROLLERS PVT LTD             SEIAA
#
#                  Proposal Status   State_Name  \
# 0                     EC Granted  WEST BENGAL
# 1  Under Verification with SCEIA  WEST BENGAL
# 2  Under Verification with SCEIA  WEST BENGAL
# 3  Under Verification with SCEIA  WEST BENGAL
# 4                    ToR Granted  WEST BENGAL
#
#                                 Activity Description
# 0  1(b) Off-shore and onshore oil and gas explora...
# 1  3(a) Metallurgical Industries (ferrous and non...
# 2  3(a) Metallurgical Industries (ferrous and non...
# 3  3(a) Metallurgical Industries (ferrous and non...
# 4  3(a) Metallurgical Industries (ferrous and non...
# ✅ Total 18 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-08-09\SEIAA_WEST_BENGAL_20260809.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: KERALA (Code: 32)
# ==================================================
# ✅ Loaded 4 unique activity/activities for 'KERALA':
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "12": "4(a) Petroleum refining industry"
#    "21": "5(c) Petro-chemical complexes (industries based on processing of petroleum fractions"
#    "24": "5(f) Synthetic organic chemicals industry"
#
# 🌍 Processing State: KERALA (Value: 32)...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 32 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 12 (4(a) Petroleum refining indust...)
#   ℹ️ No results found for State: 32 + Activity: 12. Proceeding...
#   └── ⚙️ Searching Activity ID: 21 (5(c) Petro-chemical complexes ...)
#   ℹ️ No results found for State: 32 + Activity: 21. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 32 + Activity: 24. Proceeding...
# ❌ Zero data entries found for State: KERALA
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
