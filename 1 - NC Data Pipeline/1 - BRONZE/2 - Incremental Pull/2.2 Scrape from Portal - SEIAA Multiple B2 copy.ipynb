# %%
# %load_ext autoreload
# %autoreload 2

import os
import re
import pandas as pd
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import your scraper function from the .py file
from scraper_utils import run_scraper

# Define parameters dynamically at runtime
path = os.getenv("PORTAL")
BRONZE = os.getenv("BRONZENEW")

states_input = {
    "5": "UTTARAKHAND", 
    "3": "PUNJAB",
    "2": "HIMACHAL PRADESH", 
    "1": "JAMMU AND KASHMIR", 
    "17": "MEGHALAYA",
    "6": "HARYANA", 
    "16": "TRIPURA",
    "30": "GOA", 
    "34": "PUDUCHERRY",
    "38": "THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU",
    "12": "ARUNACHAL PRADESH", 
    "35": "ANDAMAN AND NICOBAR ISLANDS", 
    "37": "LADAKH",
    "7": "DELHI", 
    "14": "MANIPUR",
    "4": "CHANDIGARH", 
    "15": "MIZORAM", 
    "13": "NAGALAND",
    "31": "LAKSHADWEEP", 
    "11": "SIKKIM"

}

# --- DYNAMIC ACTIVITIES_INPUT GENERATION & STATE ITERATION START ---
stact_path = os.getenv("STACT")
if not stact_path:
    raise ValueError("⚠️ STACT environment variable is not set.")

if not stact_path.lower().endswith((".xlsx", ".xls")):
    stact_path += ".xlsx"

if not os.path.exists(stact_path):
    raise FileNotFoundError(f"⚠️ STACT file not found at: {stact_path}")

# Read the STACT Excel file once
stact_df = pd.read_excel(stact_path)

# Standardize Location values in Excel for comparison
stact_df["_location_clean"] = (
    stact_df["Location"].astype(str).str.strip().str.upper()
)

# Regex to extract key and value from strings like: "15": "4(c) Asbestos milling...",
mapping_pattern = re.compile(r'^\s*"(.*?)":\s*"(.*?)"\s*,\s*$')

# Iterate over each state individually to optimize execution per state
for state_code, state_name in states_input.items():
    current_state_input = {state_code: state_name}
    target_state_clean = state_name.strip().upper()
    
    print(f"\n==================================================")
    print(f"🔄 Processing State: {state_name} (Code: {state_code})")
    print(f"==================================================")

    # Filter rows for the current state only
    matching_rows = stact_df[
        stact_df["_location_clean"] == target_state_clean
    ]

    # DEFENSIVE CHECK 1: Identify if State is Missing in STACT Excel
    if matching_rows.empty:
        print(f"⚠️ WARNING: State '{state_name}' from states_input was NOT found in the STACT Excel file. Skipping...")
        continue

    activities_input = {}
    unique_mappings = matching_rows["Activity Mapping"].dropna().unique()

    for entry in unique_mappings:
        entry_str = str(entry).strip()
        match = mapping_pattern.match(entry_str)
        if match:
            act_id, act_desc = match.groups()
            
            clean_act_id = act_id.strip()
            clean_act_desc = re.sub(r"\s+", " ", act_desc).strip()

            if clean_act_id not in activities_input:
                activities_input[clean_act_id] = clean_act_desc

    # DEFENSIVE CHECK 2: Ensure At Least One Activity Was Found
    if not activities_input:
        print(f"⚠️ WARNING: No valid activities found in STACT Excel for state '{state_name}'. Skipping...")
        continue

    print(f"✅ Loaded {len(activities_input)} unique activity/activities for '{state_name}':")
    for k, v in activities_input.items():
        print(f'   "{k}": "{v}"')

    # Run execution specifically for this state and its corresponding activities
    run_scraper(
        portal_url=path,
        output_base_dir=BRONZE,
        states=current_state_input,
        activities=activities_input,
        year="2026",
        headless=False  # Set to True if you don't want the browser window to open
    )
# --- DYNAMIC ACTIVITIES_INPUT GENERATION & STATE ITERATION END ---
# Out:
# ==================================================
# 🔄 Processing State: UTTARAKHAND (Code: 5)
# ==================================================
# ✅ Loaded 10 unique activity/activities for 'UTTARAKHAND':
#    "11": "3(b) Cement plants"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "27": "5(i) Pulp & Paper Industry"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "14": "4(b)(ii) Coaltar processing units"
#    "28": "5(j) Sugar Industry"
#    "6": "1(d) Thermal Power Plants"
#
# 🌍 Processing State: UTTARAKHAND (Value: 5)...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   ℹ️ No results found for State: 5 + Activity: 11. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   ℹ️ No results found for State: 5 + Activity: 25. Proceeding...
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   ℹ️ No results found for State: 5 + Activity: 75. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 5 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   ℹ️ No results found for State: 5 + Activity: 1. Proceeding...
#   └── ⚙️ Searching Activity ID: 27 (5(i) Pulp & Paper Industry...)
#   ℹ️ No results found for State: 5 + Activity: 27. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 5 + Activity: 24. Proceeding...
#   └── ⚙️ Searching Activity ID: 14 (4(b)(ii) Coaltar processing un...)
#   ℹ️ No results found for State: 5 + Activity: 14. Proceeding...
#   └── ⚙️ Searching Activity ID: 28 (5(j) Sugar Industry...)
#   ℹ️ No results found for State: 5 + Activity: 28. Proceeding...
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 6.
#
# --- Extracted Dataset Preview for UTTARAKHAND ---
#   S. No.            Proposal No.  \
# 0      1  SIA/UK/THE/580785/2026
# 1      2  SIA/UK/THE/580474/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for Transfer of EC...
#
#                                         Project Name     Location  \
# 0  25 MW Captive Co-generation Power Plant at Sit...  UTTARAKHAND
# 1  7.5 MW co-generation thermal power plant at Kh...  UTTARAKHAND
#
#               Project Proponent Issuing Authority    Proposal Status  \
# 0    GUJARAT AMBUJA EXPORTS LTD             SEIAA  Under Examination
# 1  JK Tyre & industries limited             SEIAA  Under Examination
#
#     State_Name       Activity Description
# 0  UTTARAKHAND  1(d) Thermal Power Plants
# 1  UTTARAKHAND  1(d) Thermal Power Plants
# ✅ Total 2 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_UTTARAKHAND_20260731_203215.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: PUNJAB (Code: 3)
# ==================================================
# ✅ Loaded 17 unique activity/activities for 'PUNJAB':
#    "11": "3(b) Cement plants"
#    "19": "5(a) Chemical fertilizers"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)"
#    "21": "5(c) Petro-chemical complexes (industries based on processing of petroleum fractions"
#    "12": "4(a) Petroleum refining industry"
#    "27": "5(i) Pulp & Paper Industry"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "6": "1(d) Thermal Power Plants"
#    "16": "4(d) Chlor-alkali industry"
#    "26": "5(h) Integrated paint industry"
#    "22": "5(d) Manmade fibers manufacturing"
#    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking"
#
# 🌍 Processing State: PUNJAB (Value: 3)...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   📊 Page 1: Scraping 5 records...
#   🎉 Reached final page (1) for Activity 11.
#   └── ⚙️ Searching Activity ID: 19 (5(a) Chemical fertilizers...)
#   ℹ️ No results found for State: 3 + Activity: 19. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   ℹ️ No results found for State: 3 + Activity: 25. Proceeding...
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 75.
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 9 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 10 records...
#   📊 Page 6: Scraping 10 records...
#   📊 Page 7: Scraping 10 records...
#   📊 Page 8: Scraping 10 records...
#   📊 Page 9: Scraping 10 records...
#   📊 Page 10: Scraping 10 records...
#   📊 Page 11: Scraping 6 records...
#   🎉 Reached final page (11) for Activity 1.
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   ℹ️ No results found for State: 3 + Activity: 3. Proceeding...
#   └── ⚙️ Searching Activity ID: 20 (5(b) Pesticides industry and p...)
#   ℹ️ No results found for State: 3 + Activity: 20. Proceeding...
#   └── ⚙️ Searching Activity ID: 21 (5(c) Petro-chemical complexes ...)
#   ℹ️ No results found for State: 3 + Activity: 21. Proceeding...
#   └── ⚙️ Searching Activity ID: 12 (4(a) Petroleum refining indust...)
#   ℹ️ No results found for State: 3 + Activity: 12. Proceeding...
#   └── ⚙️ Searching Activity ID: 27 (5(i) Pulp & Paper Industry...)
#   ℹ️ No results found for State: 3 + Activity: 27. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   📊 Page 1: Scraping 5 records...
#   🎉 Reached final page (1) for Activity 24.
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 6.
#   └── ⚙️ Searching Activity ID: 16 (4(d) Chlor-alkali industry...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 16.
#   └── ⚙️ Searching Activity ID: 26 (5(h) Integrated paint industry...)
#   ℹ️ No results found for State: 3 + Activity: 26. Proceeding...
#   └── ⚙️ Searching Activity ID: 22 (5(d) Manmade fibers manufactur...)
#   ℹ️ No results found for State: 3 + Activity: 22. Proceeding...
#   └── ⚙️ Searching Activity ID: 23 (5(e ) Petroleum products and p...)
#   ℹ️ No results found for State: 3 + Activity: 23. Proceeding...
#
# --- Extracted Dataset Preview for PUNJAB ---
#   S. No.             Proposal No.  \
# 0      1  SIA/PB/IND1/584275/2026
# 1      2  SIA/PB/IND1/561525/2026
# 2      3  SIA/PB/IND1/573527/2026
# 3      4  SIA/PB/IND1/572043/2026
# 4      5  SIA/PB/IND1/562097/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for EC (Category A...
# 1  Clearance Type: Application for EC (Category A...
# 2  Clearance Type: Application for Transfer of EC...
# 3  Clearance Type: Application for ToR (Category ...
# 4  Clearance Type: Application for EC (Category A...
#
#                                         Project Name Location  \
# 0  Expansion in Cement production capacity of Exi...   PUNJAB
# 1  Expansion of Cement Production Capacity (3.0 M...   PUNJAB
# 2  Application for transfer of Environmental Clea...   PUNJAB
# 3  Standalone Clinker Grinding Unit with Cement P...   PUNJAB
# 4  Standalone Grinding Unit with Cement Productio...   PUNJAB
#
#             Project Proponent Issuing Authority       Proposal Status  \
# 0    UltraTech Cement Limited             SEIAA    Under Verification
# 1  M/s. UltraTech Cement Ltd.             SEIAA    Under Verification
# 2               NAVYUG CEMENT             SEIAA            EC Granted
# 3          J K CEMENT LIMITED             SEIAA  Standard ToR Granted
# 4          JSW Cement Limited             SEIAA      Referred to SEAC
#
#   State_Name Activity Description
# 0     PUNJAB   3(b) Cement plants
# 1     PUNJAB   3(b) Cement plants
# 2     PUNJAB   3(b) Cement plants
# 3     PUNJAB   3(b) Cement plants
# 4     PUNJAB   3(b) Cement plants
# ✅ Total 128 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_PUNJAB_20260731_204053.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: HIMACHAL PRADESH (Code: 2)
# ==================================================
# ✅ Loaded 7 unique activity/activities for 'HIMACHAL PRADESH':
#    "11": "3(b) Cement plants"
#    "16": "4(d) Chlor-alkali industry"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "24": "5(f) Synthetic organic chemicals industry"
#
# 🌍 Processing State: HIMACHAL PRADESH (Value: 2)...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   ℹ️ No results found for State: 2 + Activity: 11. Proceeding...
#   └── ⚙️ Searching Activity ID: 16 (4(d) Chlor-alkali industry...)
#   ℹ️ No results found for State: 2 + Activity: 16. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 25.
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   ℹ️ No results found for State: 2 + Activity: 75. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 10 records...
#   📊 Page 6: Scraping 10 records...
#   📊 Page 7: Scraping 10 records...
#   📊 Page 8: Scraping 10 records...
#   📊 Page 9: Scraping 10 records...
#   📊 Page 10: Scraping 10 records...
#   📊 Page 11: Scraping 10 records...
#   📊 Page 12: Scraping 10 records...
#   📊 Page 13: Scraping 9 records...
#   🎉 Reached final page (13) for Activity 1.
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 2 + Activity: 24. Proceeding...
#
# --- Extracted Dataset Preview for HIMACHAL PRADESH ---
#   S. No.             Proposal No.  \
# 0      1  SIA/HP/IND2/583372/2026
# 1      2  SIA/HP/IND2/577255/2026
# 2      1  SIA/HP/IND1/565797/2026
# 3      1   SIA/HP/MIN/578818/2026
# 4      2   SIA/HP/MIN/587448/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for Amendment in E...
# 1  Clearance Type: Application for EC (Category A...
# 2  Clearance Type: Application for Validity Exten...
# 3  Clearance Type: Application for Validity Exten...
# 4  Clearance Type: Application for Corrigendum Fo...
#
#                                         Project Name          Location  \
# 0             Proposed 5 KLPD Malt Spirit Distillery  HIMACHAL PRADESH
# 1  Proposed 30 KLD Malt Spirit Distillery and 2 K...  HIMACHAL PRADESH
# 2  Application for Extension in the Validity of E...  HIMACHAL PRADESH
# 3  Extension of validity of Environment clearance...  HIMACHAL PRADESH
# 4  Extraction of sand, stone and bajri from Khasr...  HIMACHAL PRADESH
#
#                               Project Proponent Issuing Authority  \
# 0  IAN MACLEOD DISTILLERS INDIA PRIVATE LIMITED             SEIAA
# 1            ANGUS DUNDEE INDIA PRIVATE LIMITED             SEIAA
# 2               VALLEY IRON & STEEL CO. LIMITED             SEIAA
# 3                                 SHRI AMARDEEP             SEIAA
# 4     jagdambey stone crusher & Screening plant             SEIAA
#
#        Proposal Status        State_Name  \
# 0           EDS raised  HIMACHAL PRADESH
# 1  Pending at MS SEIAA  HIMACHAL PRADESH
# 2           EC Granted  HIMACHAL PRADESH
# 3   Under Verification  HIMACHAL PRADESH
# 4   Under Verification  HIMACHAL PRADESH
#
#                                 Activity Description
# 0                                  5(g) Distilleries
# 1                                  5(g) Distilleries
# 2  3(a) Metallurgical Industries (ferrous and non...
# 3                            1(a) Mining of minerals
# 4                            1(a) Mining of minerals
# ✅ Total 132 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_HIMACHAL_PRADESH_20260731_204512.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: JAMMU AND KASHMIR (Code: 1)
# ==================================================
# ✅ Loaded 6 unique activity/activities for 'JAMMU AND KASHMIR':
#    "11": "3(b) Cement plants"
#    "25": "5(g) Distilleries"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "22": "5(d) Manmade fibers manufacturing"
#
# 🌍 Processing State: JAMMU AND KASHMIR (Value: 1)...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 11.
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 25.
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 10 records...
#   📊 Page 6: Scraping 10 records...
#   📊 Page 7: Scraping 10 records...
#   📊 Page 8: Scraping 1 records...
#   🎉 Reached final page (8) for Activity 1.
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 24.
#   └── ⚙️ Searching Activity ID: 22 (5(d) Manmade fibers manufactur...)
#   ℹ️ No results found for State: 1 + Activity: 22. Proceeding...
#
# --- Extracted Dataset Preview for JAMMU AND KASHMIR ---
#   S. No.             Proposal No.  \
# 0      1  SIA/JK/IND1/576459/2026
# 1      1  SIA/JK/IND2/586587/2026
# 2      1  SIA/JK/IND1/573201/2026
# 3      2  SIA/JK/IND1/562038/2026
# 4      1   SIA/JK/MIN/556309/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for Validity Exten...
# 1  Clearance Type: Application for ToR (Category ...
# 2  Clearance Type: Application for ToR (Category ...
# 3  Clearance Type: Application for EC (Category A...
# 4  Clearance Type: Application for Validity Exten...
#
#                                         Project Name           Location  \
# 0                Mehboob Cement Industries Pvt. Ltd.  JAMMU AND KASHMIR
# 1               MANUFACTURING OF MINERAL WATER PLANT  JAMMU AND KASHMIR
# 2  Manufacturing of lead ingots, pig ingots and b...  JAMMU AND KASHMIR
# 3  Proposed New Steel manufacturing unit having c...  JAMMU AND KASHMIR
# 4  Minor Mineral (River Bed Material) Mining Proj...  JAMMU AND KASHMIR
#
#                     Project Proponent Issuing Authority  \
# 0         M/S. MEHBOOB CEMENT PVT LTD             SEIAA
# 1  AUROCILS BEVERAGES PRIVATE LIMITED             SEIAA
# 2                          M V ALLOYS             SEIAA
# 3                  GERMAN STEEL WORKS             SEIAA
# 4              M/S ARVIND KUMAR GUPTA             SEIAA
#
#                           Proposal Status         State_Name  \
# 0   DELISTED BY SYSTEM\n(at : 12/07/2026)  JAMMU AND KASHMIR
# 1                      Under Verification  JAMMU AND KASHMIR
# 2  Proposal Accepted and Referred to SEAC  JAMMU AND KASHMIR
# 3                              ADS Raised  JAMMU AND KASHMIR
# 4                      Under Verification  JAMMU AND KASHMIR
#
#                                 Activity Description
# 0                                 3(b) Cement plants
# 1                                  5(g) Distilleries
# 2  3(a) Metallurgical Industries (ferrous and non...
# 3  3(a) Metallurgical Industries (ferrous and non...
# 4                            1(a) Mining of minerals
# ✅ Total 77 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_JAMMU_AND_KASHMIR_20260731_204833.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: MEGHALAYA (Code: 17)
# ==================================================
# ✅ Loaded 4 unique activity/activities for 'MEGHALAYA':
#    "11": "3(b) Cement plants"
#    "1": "1(a) Mining of minerals"
#    "6": "1(d) Thermal Power Plants"
#    "25": "5(g) Distilleries"
#
# 🌍 Processing State: MEGHALAYA (Value: 17)...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   📊 Page 1: Scraping 3 records...
#   🎉 Reached final page (1) for Activity 11.
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 10 records...
#   📊 Page 4: Scraping 10 records...
#   📊 Page 5: Scraping 10 records...
#   📊 Page 6: Scraping 4 records...
#   🎉 Reached final page (6) for Activity 1.
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ℹ️ No results found for State: 17 + Activity: 6. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   ℹ️ No results found for State: 17 + Activity: 25. Proceeding...
#
# --- Extracted Dataset Preview for MEGHALAYA ---
#   S. No.             Proposal No.  \
# 0      1  SIA/ML/IND1/575178/2026
# 1      2  SIA/ML/IND1/570078/2026
# 2      3  SIA/ML/IND1/569540/2026
# 3      1  SIA/ML/CMIN/587001/2026
# 4      2   SIA/ML/MIN/586773/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for Corrigendum Fo...
# 1  Clearance Type: Application for EC (Category A...
# 2  Clearance Type: Application for EC (Category A...
# 3  Clearance Type: Application for ToR (Category ...
# 4  Clearance Type: Application for EC for Mining ...
#
#                                         Project Name   Location  \
# 0  Integrated Cement Plant with capacity of clink...  MEGHALAYA
# 1  Integrated Cement Plant with capacity of clink...  MEGHALAYA
# 2  Integrated Cement Plant with capacity of clink...  MEGHALAYA
# 3                   Sajay Laloo Sdaddkhar Coal Block  MEGHALAYA
# 4                                  Boulderstone Mine  MEGHALAYA
#
#       Project Proponent Issuing Authority                   Proposal Status  \
# 0  Shree Cement Limited             SEIAA                        EC Granted
# 1  Shree Cement Limited             SEIAA                        EC Granted
# 2  Shree Cement Limited             SEIAA  Proposal pulled back (withdrawn)
# 3           SAJAY LALOO             SEIAA                 Under Examination
# 4      RINALDI RYNGKSAI             SEIAA                Under Verification
#
#   State_Name     Activity Description
# 0  MEGHALAYA       3(b) Cement plants
# 1  MEGHALAYA       3(b) Cement plants
# 2  MEGHALAYA       3(b) Cement plants
# 3  MEGHALAYA  1(a) Mining of minerals
# 4  MEGHALAYA  1(a) Mining of minerals
# ✅ Total 57 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_MEGHALAYA_20260731_205048.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: HARYANA (Code: 6)
# ==================================================
# ✅ Loaded 13 unique activity/activities for 'HARYANA':
#    "11": "3(b) Cement plants"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "26": "5(h) Integrated paint industry"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)"
#    "21": "5(c) Petro-chemical complexes (industries based on processing of petroleum fractions"
#    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking"
#    "12": "4(a) Petroleum refining industry"
#    "18": "4(f) Skin/hide processing including the tanning industry"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "6": "1(d) Thermal Power Plants"
#
# 🌍 Processing State: HARYANA (Value: 6)...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 11.
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 25.
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   ℹ️ No results found for State: 6 + Activity: 75. Proceeding...
#   └── ⚙️ Searching Activity ID: 26 (5(h) Integrated paint industry...)
#   ℹ️ No results found for State: 6 + Activity: 26. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 10 records...
#   📊 Page 3: Scraping 5 records...
#   🎉 Reached final page (3) for Activity 1.
#   └── ⚙️ Searching Activity ID: 20 (5(b) Pesticides industry and p...)
#   ℹ️ No results found for State: 6 + Activity: 20. Proceeding...
#   └── ⚙️ Searching Activity ID: 21 (5(c) Petro-chemical complexes ...)
#   ℹ️ No results found for State: 6 + Activity: 21. Proceeding...
#   └── ⚙️ Searching Activity ID: 23 (5(e ) Petroleum products and p...)
#   ℹ️ No results found for State: 6 + Activity: 23. Proceeding...
#   └── ⚙️ Searching Activity ID: 12 (4(a) Petroleum refining indust...)
#   ℹ️ No results found for State: 6 + Activity: 12. Proceeding...
#   └── ⚙️ Searching Activity ID: 18 (4(f) Skin/hide processing incl...)
#   ℹ️ No results found for State: 6 + Activity: 18. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   📊 Page 1: Scraping 8 records...
#   🎉 Reached final page (1) for Activity 24.
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ℹ️ No results found for State: 6 + Activity: 6. Proceeding...
#
# --- Extracted Dataset Preview for HARYANA ---
#   S. No.             Proposal No.  \
# 0      1  SIA/HR/IND1/572153/2026
# 1      2  SIA/HR/IND1/575146/2026
# 2      1  SIA/HR/IND2/575995/2026
# 3      1  SIA/HR/IND1/522676/2026
# 4      1   SIA/HR/MIN/580711/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for Amendment in E...
# 2  Clearance Type: Application for ToR (Category ...
# 3  Clearance Type: Application for EC (Category A...
# 4  Clearance Type: Application for Amendment in E...
#
#                                         Project Name Location  \
# 0  Standalone Clinker Grinding Unit with Cement P...  HARYANA
# 1  Amendment in Existing Environmental Clearance ...  HARYANA
# 2  Expansion in capacity of grain based distiller...  HARYANA
# 3  Proposed Expansion by Augmentation of Capacity...  HARYANA
# 4  Mining of Sand (Minor Mineral) from the Riverb...  HARYANA
#
#                           Project Proponent Issuing Authority  \
# 0  JINDAL CEMENT INDUSTRIES PRIVATE LIMITED             SEIAA
# 1                        J K CEMENT LIMITED             SEIAA
# 2         NAKSHTRA BIOFUELS PRIVATE LIMITED             SEIAA
# 3                  Jindal Stainless limited             SEIAA
# 4              RAJENDER BANSAL AND SONS HUF             SEIAA
#
#                           Proposal Status State_Name  \
# 0   DELISTED BY SYSTEM\n(at : 18/06/2026)    HARYANA
# 1                        Referred to SEAC    HARYANA
# 2                    Standard ToR Granted    HARYANA
# 3                              EC Granted    HARYANA
# 4  Proposal Accepted and Referred to SEAC    HARYANA
#
#                                 Activity Description
# 0                                 3(b) Cement plants
# 1                                 3(b) Cement plants
# 2                                  5(g) Distilleries
# 3  3(a) Metallurgical Industries (ferrous and non...
# 4                            1(a) Mining of minerals
# ✅ Total 37 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_HARYANA_20260731_205540.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: TRIPURA (Code: 16)
# ==================================================
# ✅ Loaded 4 unique activity/activities for 'TRIPURA':
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#    "6": "1(d) Thermal Power Plants"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#
# 🌍 Processing State: TRIPURA (Value: 16)...
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   📊 Page 1: Scraping 5 records...
#   🎉 Reached final page (1) for Activity 3.
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ℹ️ No results found for State: 16 + Activity: 6. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 10.
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 5 records...
#   🎉 Reached final page (1) for Activity 1.
#
# --- Extracted Dataset Preview for TRIPURA ---
#   S. No.             Proposal No.  \
# 0      1  SIA/TR/IND2/581925/2026
# 1      2  SIA/TR/IND2/581795/2026
# 2      3  SIA/TR/IND2/577250/2026
# 3      4  SIA/TR/IND2/577192/2026
# 4      5  SIA/TR/IND2/566390/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for ToR (Category ...
# 2  Clearance Type: Application for ToR (Category ...
# 3  Clearance Type: Application for ToR (Category ...
# 4  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name Location  \
# 0     Drilling of Exploratory location TMAH- Cluster  TRIPURA
# 1     Drilling of exploratory Location ADAY- Cluster  TRIPURA
# 2             Drilling of Exploratory Location ROKAC  TRIPURA
# 3    Drilling of Exploratory Locations SNAA and SNAB  TRIPURA
# 4  Drilling of OALP Block Exploratory Location AA...  TRIPURA
#
#      Project Proponent Issuing Authority     Proposal Status State_Name  \
# 0  ONGC, TRIPURA ASSET             SEIAA  Under Verification    TRIPURA
# 1  ONGC, TRIPURA ASSET             SEIAA  Under Verification    TRIPURA
# 2  ONGC, TRIPURA ASSET             SEIAA  Under Verification    TRIPURA
# 3  ONGC, TRIPURA ASSET             SEIAA  Under Verification    TRIPURA
# 4  ONGC, TRIPURA ASSET             SEIAA  Under Verification    TRIPURA
#
#                                 Activity Description
# 0  1(b) Off-shore and onshore oil and gas explora...
# 1  1(b) Off-shore and onshore oil and gas explora...
# 2  1(b) Off-shore and onshore oil and gas explora...
# 3  1(b) Off-shore and onshore oil and gas explora...
# 4  1(b) Off-shore and onshore oil and gas explora...
# ✅ Total 11 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_TRIPURA_20260731_205702.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: GOA (Code: 30)
# ==================================================
# ✅ Loaded 5 unique activity/activities for 'GOA':
#    "25": "5(g) Distilleries"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "9": "2(b) Mineral beneficiation"
#    "1": "1(a) Mining of minerals"
#    "26": "5(h) Integrated paint industry"
#
# 🌍 Processing State: GOA (Value: 30)...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   ℹ️ No results found for State: 30 + Activity: 25. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 30 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 9 (2(b) Mineral beneficiation...)
#   ℹ️ No results found for State: 30 + Activity: 9. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 10 records...
#   📊 Page 2: Scraping 2 records...
#   🎉 Reached final page (2) for Activity 1.
#   └── ⚙️ Searching Activity ID: 26 (5(h) Integrated paint industry...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 26.
#
# --- Extracted Dataset Preview for GOA ---
#   S. No.            Proposal No.  \
# 0      1  SIA/GA/MIN/587378/2026
# 1      2  SIA/GA/MIN/587038/2026
# 2      3  SIA/GA/MIN/586752/2026
# 3      4  SIA/GA/MIN/582639/2026
# 4      5  SIA/GA/MIN/585198/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for ToR (Category ...
# 2  Clearance Type: Application for ToR (Category ...
# 3  Clearance Type: Application for EC for Mining ...
# 4  Clearance Type: Application for Transfer of EC...
#
#                                         Project Name Location  \
# 0  Scientific Handling and Recovery of Iron Ore f...      GOA
# 1  Scientific Handling and Recovery of Iron Ore f...      GOA
# 2  Iron Ore Dump Handling at ‘DUMP NO. 15’ (E Auc...      GOA
# 3                              ANTOREM BASALT QUARRY      GOA
# 4  Block VII Cudnem Mineral Block Iron Ore Mine o...      GOA
#
#                        Project Proponent Issuing Authority  \
# 0  SARUS INFRASTRUCTURES PRIVATE LIMITED             SEIAA
# 1  SARUS INFRASTRUCTURES PRIVATE LIMITED             SEIAA
# 2    K A I INTERNATIONAL PRIVATE LIMITED             SEIAA
# 3                          RAJENDRA NAIK             SEIAA
# 4         VEDANTA IRON AND STEEL LIMITED             SEIAA
#
#       Proposal Status State_Name     Activity Description
# 0  Under Verification        GOA  1(a) Mining of minerals
# 1  Under Verification        GOA  1(a) Mining of minerals
# 2  Under Verification        GOA  1(a) Mining of minerals
# 3  Under Verification        GOA  1(a) Mining of minerals
# 4    Referred to SEAC        GOA  1(a) Mining of minerals
# ✅ Total 13 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_GOA_20260731_205908.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: PUDUCHERRY (Code: 34)
# ==================================================
# ✅ Loaded 7 unique activity/activities for 'PUDUCHERRY':
#    "16": "4(d) Chlor-alkali industry"
#    "26": "5(h) Integrated paint industry"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)"
#    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "25": "5(g) Distilleries"
#
# 🌍 Processing State: PUDUCHERRY (Value: 34)...
#   └── ⚙️ Searching Activity ID: 16 (4(d) Chlor-alkali industry...)
#   ℹ️ No results found for State: 34 + Activity: 16. Proceeding...
#   └── ⚙️ Searching Activity ID: 26 (5(h) Integrated paint industry...)
#   ℹ️ No results found for State: 34 + Activity: 26. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 34 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 20 (5(b) Pesticides industry and p...)
#   ℹ️ No results found for State: 34 + Activity: 20. Proceeding...
#   └── ⚙️ Searching Activity ID: 23 (5(e ) Petroleum products and p...)
#   ℹ️ No results found for State: 34 + Activity: 23. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 34 + Activity: 24. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 25.
#
# --- Extracted Dataset Preview for PUDUCHERRY ---
#   S. No.             Proposal No.  \
# 0      1  SIA/PY/IND2/582669/2026
# 1      2  SIA/PY/IND2/578103/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for EC (Category A...
# 1  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name    Location  \
# 0  Proposed 25 KLPD Grain-Based Distillery for Pr...  PUDUCHERRY
# 1  Proposed 25 KLPD Grain-Based Distillery for Pr...  PUDUCHERRY
#
#    Project Proponent Issuing Authority       Proposal Status  State_Name  \
# 0  V ravitchandirane             SEIAA            ADS Raised  PUDUCHERRY
# 1  V ravitchandirane             SEIAA  Standard ToR Granted  PUDUCHERRY
#
#   Activity Description
# 0    5(g) Distilleries
# 1    5(g) Distilleries
# ✅ Total 2 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_PUDUCHERRY_20260731_210145.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU (Code: 38)
# ==================================================
# ✅ Loaded 5 unique activity/activities for 'THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU':
#    "22": "5(d) Manmade fibers manufacturing"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "2": "6(a) Pipelines"
#    "24": "5(f) Synthetic organic chemicals industry"
#
# 🌍 Processing State: THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU (Value: 38)...
#   └── ⚙️ Searching Activity ID: 22 (5(d) Manmade fibers manufactur...)
#   ℹ️ No results found for State: 38 + Activity: 22. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 38 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 1.
#   └── ⚙️ Searching Activity ID: 2 (6(a) Pipelines...)
#   ℹ️ No results found for State: 38 + Activity: 2. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 38 + Activity: 24. Proceeding...
#
# --- Extracted Dataset Preview for THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU ---
#   S. No.            Proposal No.  \
# 0      1  SIA/DN/MIN/576198/2026
# 1      2  SIA/DN/MIN/576059/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for ToR (Category ...
#
#                          Project Name  \
# 0                 M/s. Himalaya Infra
# 1  Shri Shyam Infrsolutions Pvt. Ltd.
#
#                                        Location   Project Proponent  \
# 0  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU  GOPAL LAL CHECHANI
# 1  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU       MANROOP SINGH
#
#   Issuing Authority   Proposal Status  \
# 0             SEIAA  Referred to SEAC
# 1             SEIAA  Referred to SEAC
#
#                                      State_Name     Activity Description
# 0  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU  1(a) Mining of minerals
# 1  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU  1(a) Mining of minerals
# ✅ Total 2 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_THE_DADRA_AND_NAGAR_HAVELI_AND_DAMAN_AND_DIU_20260731_210343.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: ARUNACHAL PRADESH (Code: 12)
# ==================================================
# ✅ Loaded 5 unique activity/activities for 'ARUNACHAL PRADESH':
#    "25": "5(g) Distilleries"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#    "13": "4(b) Coke oven plants"
#    "1": "1(a) Mining of minerals"
#
# 🌍 Processing State: ARUNACHAL PRADESH (Value: 12)...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   ℹ️ No results found for State: 12 + Activity: 25. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 12 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   📊 Page 1: Scraping 3 records...
#   🎉 Reached final page (1) for Activity 3.
#   └── ⚙️ Searching Activity ID: 13 (4(b) Coke oven plants...)
#   ℹ️ No results found for State: 12 + Activity: 13. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   ℹ️ No results found for State: 12 + Activity: 1. Proceeding...
#
# --- Extracted Dataset Preview for ARUNACHAL PRADESH ---
#   S. No.             Proposal No.  \
# 0      1  SIA/AR/IND2/577329/2026
# 1      2  SIA/AR/IND2/576052/2026
# 2      3  SIA/AR/IND2/569648/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for ToR (Category ...
# 2  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name           Location  \
# 0  Onshore Oil & Gas Drilling & Testing at Loc. O...  ARUNACHAL PRADESH
# 1  Onshore Oil & Gas Exploration Drilling & Testi...  ARUNACHAL PRADESH
# 2            Onshore Oil & Gas drilling at Loc. KHAS  ARUNACHAL PRADESH
#
#    Project Proponent Issuing Authority  \
# 0      OIL INDIA LTD             SEIAA
# 1      OIL INDIA LTD             SEIAA
# 2  OIL INDIA LIMITED             SEIAA
#
#                           Proposal Status         State_Name  \
# 0  Proposal Accepted and Referred to SEAC  ARUNACHAL PRADESH
# 1  Proposal Accepted and Referred to SEAC  ARUNACHAL PRADESH
# 2  Proposal Accepted and Referred to SEAC  ARUNACHAL PRADESH
#
#                                 Activity Description
# 0  1(b) Off-shore and onshore oil and gas explora...
# 1  1(b) Off-shore and onshore oil and gas explora...
# 2  1(b) Off-shore and onshore oil and gas explora...
# ✅ Total 3 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_ARUNACHAL_PRADESH_20260731_210538.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: ANDAMAN AND NICOBAR ISLANDS (Code: 35)
# ==================================================
# ✅ Loaded 3 unique activity/activities for 'ANDAMAN AND NICOBAR ISLANDS':
#    "2": "6(a) Pipelines"
#    "1": "1(a) Mining of minerals"
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#
# 🌍 Processing State: ANDAMAN AND NICOBAR ISLANDS (Value: 35)...
#   └── ⚙️ Searching Activity ID: 2 (6(a) Pipelines...)
#   ℹ️ No results found for State: 35 + Activity: 2. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 1.
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   ℹ️ No results found for State: 35 + Activity: 3. Proceeding...
#
# --- Extracted Dataset Preview for ANDAMAN AND NICOBAR ISLANDS ---
#   S. No.            Proposal No.  \
# 0      1  SIA/AN/MIN/575034/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for EC for Mining ...
#
#                                    Project Name                     Location  \
# 0  HutBay Stone Quarry for Non-Explosive Blocks  ANDAMAN AND NICOBAR ISLANDS
#
#                     Project Proponent Issuing Authority Proposal Status  \
# 0  Deputy Commissioner, South Andaman             SEIAA      EC Granted
#
#                     State_Name     Activity Description
# 0  ANDAMAN AND NICOBAR ISLANDS  1(a) Mining of minerals
# ✅ Total 1 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_ANDAMAN_AND_NICOBAR_ISLANDS_20260731_210714.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: LADAKH (Code: 37)
# ==================================================
# ✅ Loaded 1 unique activity/activities for 'LADAKH':
#    "1": "1(a) Mining of minerals"
#
# 🌍 Processing State: LADAKH (Value: 37)...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   ℹ️ No results found for State: 37 + Activity: 1. Proceeding...
# ❌ Zero data entries found for State: LADAKH
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: DELHI (Code: 7)
# ==================================================
# ✅ Loaded 4 unique activity/activities for 'DELHI':
#    "11": "3(b) Cement plants"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "6": "1(d) Thermal Power Plants"
#
# 🌍 Processing State: DELHI (Value: 7)...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   ℹ️ No results found for State: 7 + Activity: 11. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 7 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 1.
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   ℹ️ No results found for State: 7 + Activity: 6. Proceeding...
#
# --- Extracted Dataset Preview for DELHI ---
#   S. No.            Proposal No.  \
# 0      1  SIA/DL/MIN/577119/2026
#
#                                     Proposal Details     Project Name  \
# 0  Clearance Type: Application for Transfer of EC...  MOHINDER MANGLA
#
#   Location      Project Proponent Issuing Authority  \
# 0    DELHI  MOHINDER KUMAR MANGLA             SEIAA
#
#                      Proposal Status State_Name     Activity Description
# 0  Proposal returned in present form      DELHI  1(a) Mining of minerals
# ✅ Total 1 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_DELHI_20260731_210928.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: MANIPUR (Code: 14)
# ==================================================
# ✅ Loaded 1 unique activity/activities for 'MANIPUR':
#    "1": "1(a) Mining of minerals"
#
# 🌍 Processing State: MANIPUR (Value: 14)...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 3 records...
#   🎉 Reached final page (1) for Activity 1.
#
# --- Extracted Dataset Preview for MANIPUR ---
#   S. No.            Proposal No.  \
# 0      1  SIA/MN/MIN/585744/2026
# 1      2  SIA/MN/MIN/565869/2026
# 2      3  SIA/MN/MIN/565866/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for EC for Mining ...
# 1  Clearance Type: Application for ToR (Category ...
# 2  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name Location  \
# 0   SEKMAI VILLAGE QUARRYING LEASE OF SAND AND STONE  MANIPUR
# 1  MARUM AND SHALY/SLATY EARTH MINING AREA AT WAI...  MANIPUR
# 2  MARUM AND SHALY/SLATY EARTH MINING AREA AT MAP...  MANIPUR
#
#     Project Proponent Issuing Authority  \
# 0  TUNINDRO WAHENGBAM             SEIAA
# 1           raj sinam             SEIAA
# 2           raj sinam             SEIAA
#
#                          Proposal Status State_Name     Activity Description
# 0                     Under Verification    MANIPUR  1(a) Mining of minerals
# 1  DELISTED BY SYSTEM\n(at : 10/03/2026)    MANIPUR  1(a) Mining of minerals
# 2  DELISTED BY SYSTEM\n(at : 10/03/2026)    MANIPUR  1(a) Mining of minerals
# ✅ Total 3 rows scraped and saved to F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\NewRecords\2026-07-31\SEIAA_MANIPUR_20260731_210956.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: CHANDIGARH (Code: 4)
# ==================================================
# ✅ Loaded 1 unique activity/activities for 'CHANDIGARH':
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#
# 🌍 Processing State: CHANDIGARH (Value: 4)...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 4 + Activity: 10. Proceeding...
# ❌ Zero data entries found for State: CHANDIGARH
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: MIZORAM (Code: 15)
# ==================================================
# ✅ Loaded 1 unique activity/activities for 'MIZORAM':
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#
# 🌍 Processing State: MIZORAM (Value: 15)...
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   ℹ️ No results found for State: 15 + Activity: 3. Proceeding...
# ❌ Zero data entries found for State: MIZORAM
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: NAGALAND (Code: 13)
# ==================================================
# ✅ Loaded 1 unique activity/activities for 'NAGALAND':
#    "1": "1(a) Mining of minerals"
#
# 🌍 Processing State: NAGALAND (Value: 13)...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   ℹ️ No results found for State: 13 + Activity: 1. Proceeding...
# ❌ Zero data entries found for State: NAGALAND
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\LeadGen\Data Architecture\1 - Bronze\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: LAKSHADWEEP (Code: 31)
# ==================================================
# ⚠️ WARNING: State 'LAKSHADWEEP' from states_input was NOT found in the STACT Excel file. Skipping...
#
# ==================================================
# 🔄 Processing State: SIKKIM (Code: 11)
# ==================================================
# ⚠️ WARNING: State 'SIKKIM' from states_input was NOT found in the STACT Excel file. Skipping...
