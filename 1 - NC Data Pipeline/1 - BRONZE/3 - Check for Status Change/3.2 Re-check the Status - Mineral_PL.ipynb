# %%
from datetime import datetime
import os
import time
import pandas as pd
from dotenv import load_dotenv
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException, TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

load_dotenv()

# -------------------------------------------------------------
# Configuration & Environment Variables
# -------------------------------------------------------------
search_url = os.getenv("PORTAL")
non_min_path = os.getenv("Min")
silver_u_dir = os.getenv("SILVERU")

# Set TOP_N to an integer (e.g., 50) to process only the top N records, or set to None to process ALL
TOP_N = None

if not non_min_path or not os.path.exists(non_min_path):
    raise FileNotFoundError(
        f"❌ NonMin environment path not found or invalid: {non_min_path}"
    )

if not silver_u_dir:
    raise ValueError("❌ SILVERU environment variable is not set.")

os.makedirs(silver_u_dir, exist_ok=True)

# -------------------------------------------------------------
# Initialize Browser
# -------------------------------------------------------------
chrome_options = webdriver.ChromeOptions()
chrome_options.page_load_strategy = "eager"
driver = webdriver.Chrome(options=chrome_options)
driver.get(search_url)
wait = WebDriverWait(driver, 10)

# -------------------------------------------------------------
# Load Excel File from NonMin
# -------------------------------------------------------------
print(f"📂 Loading file from NonMin path: {non_min_path}")
df_leads = pd.read_excel(non_min_path)

if (
    "Proposal No." not in df_leads.columns
    or "Proposal Status" not in df_leads.columns
):
    raise KeyError(
        "The Excel file must contain both 'Proposal No.' and 'Proposal Status' columns."
    )

# Apply TOP_N slicing if specified
if TOP_N is not None and TOP_N > 0:
    df_leads = df_leads.head(TOP_N)
    print(f"⚙️ TOP_N filter active: Processing top {len(df_leads)} records.")
else:
    print(f"Loaded {len(df_leads)} rows. Starting portal check for updated proposal statuses...")

main_window = driver.current_window_handle
results = []

# -------------------------------------------------------------
# Search Loop & Status Verification
# -------------------------------------------------------------
for idx, row in df_leads.iterrows():
    proposal_no = str(row["Proposal No."]).strip()
    original_status = str(row["Proposal Status"]).strip()

    if (
        pd.isna(row["Proposal No."])
        or proposal_no == ""
        or proposal_no.lower() == "nan"
    ):
        continue

    print(f"\n[{idx + 1}/{len(df_leads)}] Checking Proposal: {proposal_no}")

    try:
        if (
            "trackYourProposal" not in driver.current_url
            or "proposal-details" in driver.current_url
        ):
            driver.get(search_url)

        proposal_input = wait.until(
            EC.visibility_of_element_located(
                (By.XPATH, "//input[@formcontrolname='proposalNumber']")
            )
        )
        proposal_input.clear()
        proposal_input.send_keys(proposal_no)

        search_button = wait.until(
            EC.element_to_be_clickable(
                (By.XPATH, "//button[@type='submit' and contains(.,'Search')]")
            )
        )
        driver.execute_script("arguments[0].click();", search_button)

        try:
            WebDriverWait(driver, 7).until(
                EC.text_to_be_present_in_element(
                    (
                        By.XPATH,
                        "//table[@id='excel-table']/tbody/tr[1]/td[2]",
                    ),
                    proposal_no,
                )
            )
        except TimeoutException:
            print(f"  ⚠️ No matching records found for: {proposal_no}. Marking as eliminated...")
            results.append({
                "Proposal No.": proposal_no,
                "Original Status": original_status,
                "Portal Status": "",
                "Flag": "eliminated"
            })
            continue

        # Extract Proposal Status (7th column: td[7])
        try:
            status_cell = driver.find_element(
                By.XPATH,
                "//table[@id='excel-table']/tbody/tr[1]/td[7]",
            )
            portal_status = status_cell.text.strip()
        except NoSuchElementException:
            portal_status = "Unknown"

        print(
            f"  -> Original Status: '{original_status}' | Portal Status: '{portal_status}'"
        )

        # Flag determination
        if (
            portal_status
            and portal_status.lower() != "unknown"
            and portal_status.lower() != original_status.lower()
        ):
            print(f"  ✨ Status change detected! Updating status to: '{portal_status}'")
            flag = "change"
        else:
            flag = "no change"

        results.append({
            "Proposal No.": proposal_no,
            "Original Status": original_status,
            "Portal Status": portal_status,
            "Flag": flag
        })

        driver.get(search_url)
        wait.until(
            EC.visibility_of_element_located(
                (By.XPATH, "//input[@formcontrolname='proposalNumber']")
            )
        )

    except Exception as e:
        print(f" ❌ Processing fail for proposal {proposal_no}: {e}")
        all_windows = driver.window_handles
        if len(all_windows) > 1:
            for extra_w in all_windows[1:]:
                driver.switch_to.window(extra_w)
                driver.close()
        driver.switch_to.window(main_window)
        driver.get(search_url)
        continue

# Quit WebDriver
driver.quit()

# -------------------------------------------------------------
# Save Output File with Datestamp at SILVERU
# -------------------------------------------------------------
cdate = datetime.now().strftime("%Y%m%d")
output_file_name = f"Min_Updated_Status_{cdate}.xlsx"
output_file_path = os.path.join(silver_u_dir, output_file_name)

# Create DataFrame with exact 4 columns required
df_output = pd.DataFrame(results, columns=["Proposal No.", "Original Status", "Portal Status", "Flag"])
df_output.to_excel(output_file_path, index=False)

print(f"\n🎉 Task complete! Processed {len(df_output)} records.")
print(f"📊 Summary by Flag:\n{df_output['Flag'].value_counts().to_string()}")
print(f"📁 Output saved to: {output_file_path}")
# Out:
# 📂 Loading file from NonMin path: F:\Chimney Work\Marketing\LeadGen\Data Architecture\2 - Silver\Mineral_PotentialLeads.xlsx
# Loaded 12746 rows. Starting portal check for updated proposal statuses...
#
# [1/12746] Checking Proposal: IA/OR/MIN/417395/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [2/12746] Checking Proposal: IA/GJ/MIN/498098/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#
# [3/12746] Checking Proposal: IA/GJ/MIN/448676/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#
# [4/12746] Checking Proposal: IA/RJ/MIN/503059/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [5/12746] Checking Proposal: IA/RJ/MIN/522836/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [6/12746] Checking Proposal: IA/OR/MIN/505821/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [7/12746] Checking Proposal: IA/AP/MIN/441553/2023
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#
# [8/12746] Checking Proposal: SIA/AP/MIN/583398/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [9/12746] Checking Proposal: SIA/AP/MIN/583396/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [10/12746] Checking Proposal: SIA/AP/MIN/582112/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [11/12746] Checking Proposal: SIA/AP/MIN/583073/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [12/12746] Checking Proposal: SIA/AP/MIN/580702/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [13/12746] Checking Proposal: SIA/AP/MIN/581773/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [14/12746] Checking Proposal: SIA/AP/MIN/583004/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
#
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [108/12746] Checking Proposal: SIA/AS/MIN/580714/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [109/12746] Checking Proposal: SIA/AS/MIN/574129/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [110/12746] Checking Proposal: SIA/AS/MIN/577299/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [111/12746] Checking Proposal: SIA/AS/MIN/577111/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [112/12746] Checking Proposal: SIA/AS/MIN/573336/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [113/12746] Checking Proposal: SIA/AS/MIN/573011/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [114/12746] Checking Proposal: SIA/AS/MIN/566297/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 28/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 28/07/2026)'
#
# [115/12746] Checking Proposal: SIA/AS/MIN/563983/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [116/12746] Checking Proposal: SIA/AS/MIN/494099/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [117/12746] Checking Proposal: SIA/AS/MIN/465467/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [118/12746] Checking Proposal: SIA/WB/MIN/576842/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'Referred to SEAC'
#   ✨ Status change detected! Updating status to: 'Referred to SEAC'
#
# [119/12746] Checking Proposal: SIA/WB/MIN/573337/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'Referred to SEAC'
#   ✨ Status change detected! Updating status to: 'Referred to SEAC'
#
# [120/12746] Checking Proposal: SIA/WB/MIN/574681/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [121/12746] Checking Proposal: SIA/WB/MIN/575073/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#
# [122/12746] Checking Proposal: SIA/WB/MIN/572612/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#
# [123/12746] Checking Proposal: SIA/WB/MIN/572220/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [124/12746] Checking Proposal: SIA/WB/MIN/573102/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [125/12746] Checking Proposal: SIA/WB/MIN/534245/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#
# [126/12746] Checking Proposal: SIA/WB/MIN/565371/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#
# [127/12746] Checking Proposal: SIA/WB/MIN/570104/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [128/12746] Checking Proposal: SIA/WB/MIN/568367/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'Referred to SEAC'
#   ✨ Status change detected! Updating status to: 'Referred to SEAC'
#
# [129/12746] Checking Proposal: SIA/WB/MIN/556062/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#
# [130/12746] Checking Proposal: SIA/WB/MIN/563338/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 05/08/2026)'
#
# [131/12746] Checking Proposal: SIA/BR/MIN/583046/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [132/12746] Checking Proposal: SIA/BR/MIN/582995/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [133/12746] Checking Proposal: SIA/BR/MIN/582591/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [134/12746] Checking Proposal: SIA/BR/MIN/582363/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [135/12746] Checking Proposal: SIA/BR/MIN/582392/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [136/12746] Checking Proposal: SIA/BR/MIN/582259/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
#
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [180/12746] Checking Proposal: SIA/CG/MIN/530199/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 03/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 03/08/2026)'
#
# [181/12746] Checking Proposal: SIA/CG/MIN/524349/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [182/12746] Checking Proposal: SIA/CG/MIN/520395/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 30/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 30/07/2026)'
#
# [183/12746] Checking Proposal: SIA/CG/MIN/516843/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [184/12746] Checking Proposal: SIA/CG/MIN/512174/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [185/12746] Checking Proposal: SIA/CG/MIN/512032/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [186/12746] Checking Proposal: SIA/CG/MIN/510833/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [187/12746] Checking Proposal: SIA/CG/MIN/510221/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 24/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 24/07/2026)'
#
# [188/12746] Checking Proposal: SIA/CG/MIN/509136/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 24/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 24/07/2026)'
#
# [189/12746] Checking Proposal: SIA/CG/MIN/506685/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [190/12746] Checking Proposal: SIA/CG/MIN/505000/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [191/12746] Checking Proposal: SIA/CG/MIN/504191/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [192/12746] Checking Proposal: SIA/CG/MIN/503243/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [193/12746] Checking Proposal: SIA/CG/MIN/503082/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [194/12746] Checking Proposal: SIA/CG/MIN/503011/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 03/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 03/08/2026)'
#
# [195/12746] Checking Proposal: SIA/CG/MIN/464290/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [196/12746] Checking Proposal: SIA/CG/MIN/464531/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [197/12746] Checking Proposal: SIA/CG/MIN/470619/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [198/12746] Checking Proposal: SIA/CG/MIN/479200/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [199/12746] Checking Proposal: SIA/CG/MIN/468506/2024
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [200/12746] Checking Proposal: SIA/GJ/MIN/569280/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [201/12746] Checking Proposal: SIA/GJ/MIN/576556/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [202/12746] Checking Proposal: SIA/GJ/MIN/575238/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 06/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 06/08/2026)'
#
# [203/12746] Checking Proposal: SIA/GJ/MIN/575998/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [204/12746] Checking Proposal: SIA/GJ/MIN/575767/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [205/12746] Checking Proposal: SIA/GJ/MIN/575438/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [206/12746] Checking Proposal: SIA/GJ/MIN/539131/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [207/12746] Checking Proposal: SIA/GJ/MIN/558913/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 06/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 06/08/2026)'
#
# [208/12746] Checking Proposal: SIA/GJ/MIN/575377/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [209/12746] Checking Proposal: SIA/GJ/MIN/573633/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [210/12746] Checking Proposal: SIA/GJ/MIN/573638/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [211/12746] Checking Proposal: SIA/GJ/MIN/573622/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [212/12746] Checking Proposal: SIA/GJ/MIN/575042/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 03/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 03/08/2026)'
#
# [213/12746] Checking Proposal: SIA/GJ/MIN/574973/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [214/12746] Checking Proposal: SIA/GJ/MIN/574960/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [215/12746] Checking Proposal: SIA/GJ/MIN/574824/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [216/12746] Checking Proposal: SIA/GJ/MIN/574754/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [217/12746] Checking Proposal: SIA/GJ/MIN/574429/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [218/12746] Checking Proposal: SIA/GJ/MIN/574408/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [219/12746] Checking Proposal: SIA/GJ/MIN/574373/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [220/12746] Checking Proposal: SIA/GJ/MIN/574145/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 03/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 03/08/2026)'
#
# [221/12746] Checking Proposal: SIA/GJ/MIN/573900/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [222/12746] Checking Proposal: SIA/GJ/MIN/573915/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [223/12746] Checking Proposal: SIA/GJ/MIN/573612/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 29/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 29/07/2026)'
#
# [224/12746] Checking Proposal: SIA/GJ/MIN/573617/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 29/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 29/07/2026)'
#
# [225/12746] Checking Proposal: SIA/GJ/MIN/573583/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 29/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 29/07/2026)'
#
# [226/12746] Checking Proposal: SIA/GJ/MIN/572821/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [227/12746] Checking Proposal: SIA/GJ/MIN/573507/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 29/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 29/07/2026)'
#
# [228/12746] Checking Proposal: SIA/GJ/MIN/573165/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [229/12746] Checking Proposal: SIA/GJ/MIN/573091/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [230/12746] Checking Proposal: SIA/GJ/MIN/572925/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [231/12746] Checking Proposal: SIA/GJ/MIN/572959/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [232/12746] Checking Proposal: SIA/GJ/MIN/572685/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [233/12746] Checking Proposal: SIA/GJ/MIN/559678/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#
# [234/12746] Checking Proposal: SIA/GJ/MIN/552815/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 21/07/2026)'
#
# [235/12746] Checking Proposal: SIA/GJ/MIN/553959/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'DELISTED BY SYSTEM
# (at : 01/08/2026)'
#   ✨ Status change detected! Updating status to: 'DELISTED BY SYSTEM
# (at : 01/08/2026)'
#
# [236/12746] Checking Proposal: SIA/GJ/MIN/571557/2026
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
#
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [350/12746] Checking Proposal: SIA/KL/MIN/470315/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'ADS Raised'
#
# [351/12746] Checking Proposal: SIA/KL/MIN/555068/2025
#   -> Original Status: 'ADS Raised' | Portal Status: 'Referred to SEAC'
# ...
#
# [12658/12746] Checking Proposal: SIA/UP/MIN/586367/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12659/12746] Checking Proposal: SIA/UP/MIN/586436/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12660/12746] Checking Proposal: SIA/UP/MIN/586335/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12661/12746] Checking Proposal: SIA/UP/MIN/583861/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12662/12746] Checking Proposal: SIA/UP/MIN/584541/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12663/12746] Checking Proposal: SIA/UP/MIN/585570/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12664/12746] Checking Proposal: SIA/UP/MIN/586190/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12665/12746] Checking Proposal: SIA/UP/MIN/586045/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12666/12746] Checking Proposal: SIA/WB/MIN/584440/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12667/12746] Checking Proposal: SIA/WB/MIN/585160/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12668/12746] Checking Proposal: SIA/WB/MIN/585240/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12669/12746] Checking Proposal: SIA/WB/MIN/567396/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12670/12746] Checking Proposal: SIA/WB/MIN/570003/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12671/12746] Checking Proposal: SIA/WB/MIN/557301/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12672/12746] Checking Proposal: SIA/WB/MIN/581021/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12673/12746] Checking Proposal: SIA/WB/MIN/585159/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12674/12746] Checking Proposal: SIA/WB/MIN/585163/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12675/12746] Checking Proposal: SIA/WB/MIN/585161/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12676/12746] Checking Proposal: SIA/WB/MIN/585165/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12677/12746] Checking Proposal: SIA/WB/MIN/584314/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12678/12746] Checking Proposal: SIA/WB/MIN/574162/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12679/12746] Checking Proposal: SIA/WB/MIN/581163/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12680/12746] Checking Proposal: SIA/WB/MIN/573764/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12681/12746] Checking Proposal: SIA/WB/MIN/573304/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12682/12746] Checking Proposal: SIA/WB/MIN/573446/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12683/12746] Checking Proposal: SIA/WB/MIN/572169/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12684/12746] Checking Proposal: SIA/WB/MIN/571612/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12685/12746] Checking Proposal: SIA/WB/MIN/571776/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12686/12746] Checking Proposal: SIA/WB/MIN/573513/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12687/12746] Checking Proposal: SIA/WB/MIN/572531/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12688/12746] Checking Proposal: SIA/WB/MIN/571993/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12689/12746] Checking Proposal: SIA/WB/MIN/571594/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12690/12746] Checking Proposal: SIA/WB/MIN/572398/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12691/12746] Checking Proposal: SIA/WB/MIN/572264/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification with SCEIA'
#   ✨ Status change detected! Updating status to: 'Under Verification with SCEIA'
#
# [12692/12746] Checking Proposal: SIA/AP/MIN/587449/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12693/12746] Checking Proposal: SIA/AP/MIN/587169/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Proposal Accepted and Referred to SEAC'
#   ✨ Status change detected! Updating status to: 'Proposal Accepted and Referred to SEAC'
#
# [12694/12746] Checking Proposal: SIA/AP/MIN/587321/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12695/12746] Checking Proposal: SIA/AP/MIN/585422/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12696/12746] Checking Proposal: SIA/AP/MIN/584436/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Proposal Accepted and Referred to SEAC'
#   ✨ Status change detected! Updating status to: 'Proposal Accepted and Referred to SEAC'
#
# [12697/12746] Checking Proposal: SIA/AP/MIN/587220/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12698/12746] Checking Proposal: SIA/AP/MIN/587063/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Proposal Accepted and Referred to SEAC'
#   ✨ Status change detected! Updating status to: 'Proposal Accepted and Referred to SEAC'
#
# [12699/12746] Checking Proposal: SIA/BR/MIN/587425/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12700/12746] Checking Proposal: SIA/BR/MIN/587385/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12701/12746] Checking Proposal: SIA/BR/MIN/587284/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12702/12746] Checking Proposal: SIA/BR/MIN/587298/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12703/12746] Checking Proposal: SIA/BR/MIN/587304/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12704/12746] Checking Proposal: SIA/CG/MIN/587087/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12705/12746] Checking Proposal: SIA/GA/MIN/587378/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12706/12746] Checking Proposal: SIA/HP/MIN/578818/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12707/12746] Checking Proposal: SIA/HP/MIN/587448/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12708/12746] Checking Proposal: SIA/HP/MIN/582174/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12709/12746] Checking Proposal: SIA/HP/MIN/578848/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12710/12746] Checking Proposal: SIA/JK/MIN/485599/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12711/12746] Checking Proposal: SIA/JH/MIN/587451/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12712/12746] Checking Proposal: SIA/JH/MIN/587260/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12713/12746] Checking Proposal: SIA/KA/MIN/587315/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12714/12746] Checking Proposal: SIA/KA/MIN/587303/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12715/12746] Checking Proposal: SIA/KA/MIN/587294/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12716/12746] Checking Proposal: SIA/KA/MIN/587387/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12717/12746] Checking Proposal: SIA/KA/MIN/587443/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12718/12746] Checking Proposal: SIA/KA/MIN/587316/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12719/12746] Checking Proposal: SIA/KL/MIN/587353/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12720/12746] Checking Proposal: SIA/MP/MIN/586850/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12721/12746] Checking Proposal: SIA/MP/MIN/587029/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12722/12746] Checking Proposal: SIA/MP/MIN/582770/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12723/12746] Checking Proposal: SIA/MH/MIN/587170/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Proposal Accepted and Referred to SEAC'
#   ✨ Status change detected! Updating status to: 'Proposal Accepted and Referred to SEAC'
#
# [12724/12746] Checking Proposal: SIA/MH/MIN/586259/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Referred to SEAC'
#   ✨ Status change detected! Updating status to: 'Referred to SEAC'
#
# [12725/12746] Checking Proposal: SIA/OR/MIN/583438/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12726/12746] Checking Proposal: SIA/OR/MIN/587343/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12727/12746] Checking Proposal: SIA/OR/MIN/587338/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12728/12746] Checking Proposal: SIA/OR/MIN/587300/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12729/12746] Checking Proposal: SIA/OR/MIN/587164/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12730/12746] Checking Proposal: SIA/RJ/MIN/587379/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12731/12746] Checking Proposal: SIA/RJ/MIN/587436/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12732/12746] Checking Proposal: SIA/RJ/MIN/582565/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12733/12746] Checking Proposal: SIA/RJ/MIN/551240/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12734/12746] Checking Proposal: SIA/RJ/MIN/550471/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12735/12746] Checking Proposal: SIA/RJ/MIN/587082/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12736/12746] Checking Proposal: SIA/RJ/MIN/586717/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12737/12746] Checking Proposal: SIA/RJ/MIN/587302/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12738/12746] Checking Proposal: SIA/RJ/MIN/587108/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12739/12746] Checking Proposal: SIA/RJ/MIN/587182/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12740/12746] Checking Proposal: SIA/RJ/MIN/587172/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'EDS raised'
#   ✨ Status change detected! Updating status to: 'EDS raised'
#
# [12741/12746] Checking Proposal: SIA/TN/MIN/587051/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12742/12746] Checking Proposal: SIA/TN/MIN/587059/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12743/12746] Checking Proposal: SIA/TN/MIN/587218/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12744/12746] Checking Proposal: SIA/UP/MIN/587410/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12745/12746] Checking Proposal: SIA/UP/MIN/587398/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# [12746/12746] Checking Proposal: SIA/UP/MIN/587193/2026
#   -> Original Status: 'Under Verification' | Portal Status: 'Under Verification'
#
# 🎉 Task complete! Processed 12746 records.
# 📊 Summary by Flag:
# Flag
# no change     10263
# change         2433
# eliminated       50
# 📁 Output saved to: F:\Chimney Work\Marketing\LeadGen\Data Architecture\2 - SILVER\Updates\NonMin_Updated_Status_20260806.xlsx
