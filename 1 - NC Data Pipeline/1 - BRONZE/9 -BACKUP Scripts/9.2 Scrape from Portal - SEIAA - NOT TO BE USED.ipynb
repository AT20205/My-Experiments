# %%
# %load_ext autoreload
# %autoreload 2

import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import your scraper function from the .py file
from scraper_utils import run_scraper

# Define parameters dynamically at runtime
path = os.getenv("PORTAL")
BRONZE = os.getenv("BRONZENEW")

states_input = {
    "35": "ANDAMAN AND NICOBAR ISLANDS", "28": "ANDHRA PRADESH", "12": "ARUNACHAL PRADESH", 
    "18": "ASSAM", "10": "BIHAR", "4": "CHANDIGARH", "22": "CHHATTISGARH", "7": "DELHI", 
    "30": "GOA", "24": "GUJARAT", "6": "HARYANA", "2": "HIMACHAL PRADESH", "1": "JAMMU AND KASHMIR", 
    "20": "JHARKHAND", "29": "KARNATAKA", "32": "KERALA", "37": "LADAKH", "31": "LAKSHADWEEP", 
    "23": "MADHYA PRADESH", "27": "MAHARASHTRA", "14": "MANIPUR", "17": "MEGHALAYA", "15": "MIZORAM", 
    "13": "NAGALAND", "21": "ODISHA", "34": "PUDUCHERRY", "3": "PUNJAB", "8": "RAJASTHAN", 
    "11": "SIKKIM", "33": "TAMIL NADU", "36": "TELANGANA", 
    "38": "THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU", "16": "TRIPURA", "5": "UTTARAKHAND", 
    "9": "UTTAR PRADESH", "19": "WEST BENGAL"
}

activities_input = {
    
    "15": "4(c) Asbestos milling / asbestos-based products",
    "11": "3(b) Cement plants", 
    "19": "5(a) Chemical fertilizers", 
    "16": "4(d) Chlor-alkali industry",
    "14": "4(b)(ii) Coaltar processing units", 
    "13": "4(b) Coke oven plants",
    "25": "5(g) Distilleries",
    "75": "5(ga) Grain based distilleries", 
    "26": "5(h) Integrated paint industry", 
    "22": "5(d) Manmade fibers manufacturing",
    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)",
    "1": "1(a) Mining of minerals", 
    "9": "2(b) Mineral beneficiation",
    "7": "1(e) Nuclear power projects and processing of nuclear fuel",
    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production",
    "79": "2(c) Pellet Plant", 
    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)",
    "21": "5(c) Petro-chemical complexes (industries based on processing of petroleum fractions",
    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking",
    "12": "4(a) Petroleum refining industry", 
    "2": "6(a) Pipelines", 
    "27": "5(i) Pulp & Paper Industry", 
    "30": "7(b) Ship breaking yards including ship breaking units", 
    "18": "4(f) Skin/hide processing including the tanning industry",
    "77": "1(a)(ii) Slurry pipelines passing through national parks / sanctuaries / coral reefs, ecologically sensitive areas",
    "17": "4(e) Soda ash Industry", 
    "28": "5(j) Sugar Industry", 
    "24": "5(f) Synthetic organic chemicals industry",
    "6": "1(d) Thermal Power Plants"
}

# Run the execution
run_scraper(
    portal_url=path,
    output_base_dir=BRONZE,
    states=states_input,
    activities=activities_input,
    year="2026",
    headless=False  # Set to True if you don't want the browser window to open
)

# %%
# %load_ext autoreload
# %autoreload 2

import os
import re
import pandas as pd
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import your scraper function from the .py file
from scraper_utils import run_scraper

# Define parameters dynamically at runtime
path = os.getenv("PORTAL")
BRONZE = os.getenv("BRONZENEW")

states_input = {
    "5": "UTTARAKHAND", 
    "34": "PUDUCHERRY",
    "38": "THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU",
    "35": "ANDAMAN AND NICOBAR ISLANDS"
}

# --- DYNAMIC ACTIVITIES_INPUT GENERATION & STATE ITERATION START ---
stact_path = os.getenv("STACT")
if not stact_path:
    raise ValueError("⚠️ STACT environment variable is not set.")

if not stact_path.lower().endswith((".xlsx", ".xls")):
    stact_path += ".xlsx"

if not os.path.exists(stact_path):
    raise FileNotFoundError(f"⚠️ STACT file not found at: {stact_path}")

# Read the STACT Excel file once
stact_df = pd.read_excel(stact_path)

# Standardize Location values in Excel for comparison
stact_df["_location_clean"] = (
    stact_df["Location"].astype(str).str.strip().str.upper()
)

# Regex to extract key and value from strings like: "15": "4(c) Asbestos milling...",
mapping_pattern = re.compile(r'^\s*"(.*?)":\s*"(.*?)"\s*,\s*$')

# Iterate over each state individually to optimize execution per state
for state_code, state_name in states_input.items():
    current_state_input = {state_code: state_name}
    target_state_clean = state_name.strip().upper()
    
    print(f"\n==================================================")
    print(f"🔄 Processing State: {state_name} (Code: {state_code})")
    print(f"==================================================")

    # Filter rows for the current state only
    matching_rows = stact_df[
        stact_df["_location_clean"] == target_state_clean
    ]

    # DEFENSIVE CHECK 1: Identify if State is Missing in STACT Excel
    if matching_rows.empty:
        print(f"⚠️ WARNING: State '{state_name}' from states_input was NOT found in the STACT Excel file. Skipping...")
        continue

    activities_input = {}
    unique_mappings = matching_rows["Activity Mapping"].dropna().unique()

    for entry in unique_mappings:
        entry_str = str(entry).strip()
        match = mapping_pattern.match(entry_str)
        if match:
            act_id, act_desc = match.groups()
            
            clean_act_id = act_id.strip()
            clean_act_desc = re.sub(r"\s+", " ", act_desc).strip()

            if clean_act_id not in activities_input:
                activities_input[clean_act_id] = clean_act_desc

    # DEFENSIVE CHECK 2: Ensure At Least One Activity Was Found
    if not activities_input:
        print(f"⚠️ WARNING: No valid activities found in STACT Excel for state '{state_name}'. Skipping...")
        continue

    print(f"✅ Loaded {len(activities_input)} unique activity/activities for '{state_name}':")
    for k, v in activities_input.items():
        print(f'   "{k}": "{v}"')

    # Run execution specifically for this state and its corresponding activities
    run_scraper(
        portal_url=path,
        output_base_dir=BRONZE,
        states=current_state_input,
        activities=activities_input,
        year="2026",
        headless=False  # Set to True if you don't want the browser window to open
    )
# --- DYNAMIC ACTIVITIES_INPUT GENERATION & STATE ITERATION END ---
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# ==================================================
# 🔄 Processing State: UTTARAKHAND (Code: 5)
# ==================================================
# ✅ Loaded 10 unique activity/activities for 'UTTARAKHAND':
#    "11": "3(b) Cement plants"
#    "25": "5(g) Distilleries"
#    "75": "5(ga) Grain based distilleries"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "27": "5(i) Pulp & Paper Industry"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "14": "4(b)(ii) Coaltar processing units"
#    "28": "5(j) Sugar Industry"
#    "6": "1(d) Thermal Power Plants"
#
# 🌍 Processing State: UTTARAKHAND (Value: 5)...
#   └── ⚙️ Searching Activity ID: 11 (3(b) Cement plants...)
#   ℹ️ No results found for State: 5 + Activity: 11. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   ℹ️ No results found for State: 5 + Activity: 25. Proceeding...
#   └── ⚙️ Searching Activity ID: 75 (5(ga) Grain based distilleries...)
#   ℹ️ No results found for State: 5 + Activity: 75. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 5 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   ℹ️ No results found for State: 5 + Activity: 1. Proceeding...
#   └── ⚙️ Searching Activity ID: 27 (5(i) Pulp & Paper Industry...)
#   ℹ️ No results found for State: 5 + Activity: 27. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 5 + Activity: 24. Proceeding...
#   └── ⚙️ Searching Activity ID: 14 (4(b)(ii) Coaltar processing un...)
#   ℹ️ No results found for State: 5 + Activity: 14. Proceeding...
#   └── ⚙️ Searching Activity ID: 28 (5(j) Sugar Industry...)
#   ℹ️ No results found for State: 5 + Activity: 28. Proceeding...
#   └── ⚙️ Searching Activity ID: 6 (1(d) Thermal Power Plants...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 6.
#
# --- Extracted Dataset Preview for UTTARAKHAND ---
#   S. No.            Proposal No.  \
# 0      1  SIA/UK/THE/580785/2026
# 1      2  SIA/UK/THE/580474/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for Transfer of EC...
#
#                                         Project Name     Location  \
# 0  25 MW Captive Co-generation Power Plant at Sit...  UTTARAKHAND
# 1  7.5 MW co-generation thermal power plant at Kh...  UTTARAKHAND
#
#               Project Proponent Issuing Authority    Proposal Status  \
# 0    GUJARAT AMBUJA EXPORTS LTD             SEIAA  Under Examination
# 1  JK Tyre & industries limited             SEIAA  Under Examination
#
#     State_Name       Activity Description
# 0  UTTARAKHAND  1(d) Thermal Power Plants
# 1  UTTARAKHAND  1(d) Thermal Power Plants
# ✅ Total 2 rows scraped and saved to F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\NewRecords\2026-07-30\SEIAA_UTTARAKHAND_20260730_193400.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: PUDUCHERRY (Code: 34)
# ==================================================
# ✅ Loaded 7 unique activity/activities for 'PUDUCHERRY':
#    "16": "4(d) Chlor-alkali industry"
#    "26": "5(h) Integrated paint industry"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)"
#    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking"
#    "24": "5(f) Synthetic organic chemicals industry"
#    "25": "5(g) Distilleries"
#
# 🌍 Processing State: PUDUCHERRY (Value: 34)...
#   └── ⚙️ Searching Activity ID: 16 (4(d) Chlor-alkali industry...)
#   ℹ️ No results found for State: 34 + Activity: 16. Proceeding...
#   └── ⚙️ Searching Activity ID: 26 (5(h) Integrated paint industry...)
#   ℹ️ No results found for State: 34 + Activity: 26. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 34 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 20 (5(b) Pesticides industry and p...)
#   ℹ️ No results found for State: 34 + Activity: 20. Proceeding...
#   └── ⚙️ Searching Activity ID: 23 (5(e ) Petroleum products and p...)
#   ℹ️ No results found for State: 34 + Activity: 23. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 34 + Activity: 24. Proceeding...
#   └── ⚙️ Searching Activity ID: 25 (5(g) Distilleries...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 25.
#
# --- Extracted Dataset Preview for PUDUCHERRY ---
#   S. No.             Proposal No.  \
# 0      1  SIA/PY/IND2/582669/2026
# 1      2  SIA/PY/IND2/578103/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for EC (Category A...
# 1  Clearance Type: Application for ToR (Category ...
#
#                                         Project Name    Location  \
# 0  Proposed 25 KLPD Grain-Based Distillery for Pr...  PUDUCHERRY
# 1  Proposed 25 KLPD Grain-Based Distillery for Pr...  PUDUCHERRY
#
#    Project Proponent Issuing Authority       Proposal Status  State_Name  \
# 0  V ravitchandirane             SEIAA            ADS Raised  PUDUCHERRY
# 1  V ravitchandirane             SEIAA  Standard ToR Granted  PUDUCHERRY
#
#   Activity Description
# 0    5(g) Distilleries
# 1    5(g) Distilleries
# ✅ Total 2 rows scraped and saved to F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\NewRecords\2026-07-30\SEIAA_PUDUCHERRY_20260730_193630.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU (Code: 38)
# ==================================================
# ✅ Loaded 5 unique activity/activities for 'THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU':
#    "22": "5(d) Manmade fibers manufacturing"
#    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)"
#    "1": "1(a) Mining of minerals"
#    "2": "6(a) Pipelines"
#    "24": "5(f) Synthetic organic chemicals industry"
#
# 🌍 Processing State: THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU (Value: 38)...
#   └── ⚙️ Searching Activity ID: 22 (5(d) Manmade fibers manufactur...)
#   ℹ️ No results found for State: 38 + Activity: 22. Proceeding...
#   └── ⚙️ Searching Activity ID: 10 (3(a) Metallurgical Industries ...)
#   ℹ️ No results found for State: 38 + Activity: 10. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 2 records...
#   🎉 Reached final page (1) for Activity 1.
#   └── ⚙️ Searching Activity ID: 2 (6(a) Pipelines...)
#   ℹ️ No results found for State: 38 + Activity: 2. Proceeding...
#   └── ⚙️ Searching Activity ID: 24 (5(f) Synthetic organic chemica...)
#   ℹ️ No results found for State: 38 + Activity: 24. Proceeding...
#
# --- Extracted Dataset Preview for THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU ---
#   S. No.            Proposal No.  \
# 0      1  SIA/DN/MIN/576198/2026
# 1      2  SIA/DN/MIN/576059/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for ToR (Category ...
# 1  Clearance Type: Application for ToR (Category ...
#
#                          Project Name  \
# 0                 M/s. Himalaya Infra
# 1  Shri Shyam Infrsolutions Pvt. Ltd.
#
#                                        Location   Project Proponent  \
# 0  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU  GOPAL LAL CHECHANI
# 1  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU       MANROOP SINGH
#
#   Issuing Authority   Proposal Status  \
# 0             SEIAA  Referred to SEAC
# 1             SEIAA  Referred to SEAC
#
#                                      State_Name     Activity Description
# 0  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU  1(a) Mining of minerals
# 1  THE DADRA AND NAGAR HAVELI AND DAMAN AND DIU  1(a) Mining of minerals
# ✅ Total 2 rows scraped and saved to F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\NewRecords\2026-07-30\SEIAA_THE_DADRA_AND_NAGAR_HAVELI_AND_DAMAN_AND_DIU_20260730_193823.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\Logs.xlsx
#
# ==================================================
# 🔄 Processing State: ANDAMAN AND NICOBAR ISLANDS (Code: 35)
# ==================================================
# ✅ Loaded 3 unique activity/activities for 'ANDAMAN AND NICOBAR ISLANDS':
#    "2": "6(a) Pipelines"
#    "1": "1(a) Mining of minerals"
#    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production"
#
# 🌍 Processing State: ANDAMAN AND NICOBAR ISLANDS (Value: 35)...
#   └── ⚙️ Searching Activity ID: 2 (6(a) Pipelines...)
#   ℹ️ No results found for State: 35 + Activity: 2. Proceeding...
#   └── ⚙️ Searching Activity ID: 1 (1(a) Mining of minerals...)
#   📊 Page 1: Scraping 1 records...
#   🎉 Reached final page (1) for Activity 1.
#   └── ⚙️ Searching Activity ID: 3 (1(b) Off-shore and onshore oil...)
#   ℹ️ No results found for State: 35 + Activity: 3. Proceeding...
#
# --- Extracted Dataset Preview for ANDAMAN AND NICOBAR ISLANDS ---
#   S. No.            Proposal No.  \
# 0      1  SIA/AN/MIN/575034/2026
#
#                                     Proposal Details  \
# 0  Clearance Type: Application for EC for Mining ...
#
#                                    Project Name                     Location  \
# 0  HutBay Stone Quarry for Non-Explosive Blocks  ANDAMAN AND NICOBAR ISLANDS
#
#                     Project Proponent Issuing Authority Proposal Status  \
# 0  Deputy Commissioner, South Andaman             SEIAA      EC Granted
#
#                     State_Name     Activity Description
# 0  ANDAMAN AND NICOBAR ISLANDS  1(a) Mining of minerals
# ✅ Total 1 rows scraped and saved to F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\NewRecords\2026-07-30\SEIAA_ANDAMAN_AND_NICOBAR_ISLANDS_20260730_193931.xlsx
# 📝 Scraping log updated at: F:\Chimney Work\Marketing\Parivesh Work\Data Architecture\Silver\Logs.xlsx

# %%
# %load_ext autoreload
# %autoreload 2

import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Import your scraper function from the .py file
from scraper_utils import run_scraper

# Define parameters dynamically at runtime
path = os.getenv("PORTAL")
BRONZE = os.getenv("BRONZENEW")

states_input = {
    "9": "UTTAR PRADESH"
    
}


activities_input = {
    
    "15": "4(c) Asbestos milling / asbestos-based products",
    "11": "3(b) Cement plants", 
    "19": "5(a) Chemical fertilizers", 
    "16": "4(d) Chlor-alkali industry",
    "14": "4(b)(ii) Coaltar processing units", 
    "13": "4(b) Coke oven plants",
    "25": "5(g) Distilleries",
    "75": "5(ga) Grain based distilleries", 
    "26": "5(h) Integrated paint industry", 
    "22": "5(d) Manmade fibers manufacturing",
    "10": "3(a) Metallurgical Industries (ferrous and non ferrous)",
    "1": "1(a) Mining of minerals", 
    "9": "2(b) Mineral beneficiation",
    "7": "1(e) Nuclear power projects and processing of nuclear fuel",
    "3": "1(b) Off-shore and onshore oil and gas exploration, development and production",
    "79": "2(c) Pellet Plant", 
    "20": "5(b) Pesticides industry and pesticide specific intermediates (excluding formulations)",
    "21": "5(c) Petro-chemical complexes (industries based on processing of petroleum fractions",
    "23": "5(e ) Petroleum products and petrochemical based processing such as production of carbon black and electrode grade graphite (processes other than cracking",
    "12": "4(a) Petroleum refining industry", 
    "2": "6(a) Pipelines", 
    "27": "5(i) Pulp & Paper Industry", 
    "30": "7(b) Ship breaking yards including ship breaking units", 
    "18": "4(f) Skin/hide processing including the tanning industry",
    "77": "1(a)(ii) Slurry pipelines passing through national parks / sanctuaries / coral reefs, ecologically sensitive areas",
    "17": "4(e) Soda ash Industry", 
    "28": "5(j) Sugar Industry", 
    "24": "5(f) Synthetic organic chemicals industry",
    "6": "1(d) Thermal Power Plants"
}

# Run the execution
run_scraper(
    portal_url=path,
    output_base_dir=BRONZE,
    states=states_input,
    activities=activities_input,
    year="2026",
    headless=False  # Set to True if you don't want the browser window to open
)
